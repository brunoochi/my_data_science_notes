# %% [markdown]
# # Project K
# Korean pop culture has grown strongly in and outside Asia. The music scene has seen an explosion of commercially successful artists and I find it quite hard to keep up with the latest trends. In this project, I experiment with two free API services - **Last.FM** and **Twitter**. I build a dataset containing top k-pop albums linked to the artists' official twitter accounts and use the data to feed a monitoring dashboard built in Tableau.
#
# In the dashboard, I want to see album data, artist latest tweets, and some basic visualizations showing metrics such as track playcount, Twitter followers, likes, retweets and etc. The objective of this project is to get familiar with how APIs work, get some practice with pandas data wrangling, and test Tableau Public.

# %%
# Start by importing libraries
import requests
import json
import pandas as pd
import time

# %% [markdown]
# # Part A - Last.FM API
# ### 1) Extract Last.FM data
# Last.FM is a music streaming website that has a great public API available for use. After quickly reading the documentation and performing some tests, I decided to use Python's requests library to pass arguments and get data. All important argumnents are passed in payload_album. Notice that I am using `'method': 'getTopAlbums'` and `'tag': 'kpop'` to get top albums tagged as k-pop.

# %%
# LastFM API

# API_KEY and API_SECRET
API_KEY = "b3e2c8ae896f92285eba81fcfac559dd"
API_SECRET = "73b32d6ab2954d5088e5043e479ba0e6"

# Set headers and payload
headers = {'user-agent': 'ochbruno'}
payload_album = {'api_key': API_KEY, 'method': 'tag.getTopAlbums', 'tag':'kpop', 'format': 'json'}

# Get top kpop albuns
top_albums_r = requests.get('https://ws.audioscrobbler.com/2.0/', headers=headers, params=payload_album)

# Check URL of the request
top_albums_r
# Out:
# <Response [200]>

# %% [markdown]
# API returned **Response 200**, which means my request was sucessful. Now, I want check the data and see how it is structured.
#
# One of the argumets in the payload was `'format':'json'`, which means that I asked the API to return the data in JSON format (default was in XML). Now, I need to use the json library to be able to navigate the data in the same way I would do with Python dictionaries and lists.

# %%
# Data output: check first entry
top_albums_r.json()['albums']['album'][0]
# Out:
# {'name': 'Dynamite',
#  'mbid': '',
#  'url': 'https://www.last.fm/music/BTS',
#  'artist': {'name': 'BTS',
#   'mbid': '0d79fe8e-ba27-4859-bb8c-2f255f346853',
#   'url': 'https://www.last.fm/music/BTS'},
#  'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/41b15d8a0ad6a81323b598bfb19cede9.png',
#    'size': 'small'},
#   {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/41b15d8a0ad6a81323b598bfb19cede9.png',
#    'size': 'medium'},
#   {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/41b15d8a0ad6a81323b598bfb19cede9.png',
#    'size': 'large'},
#   {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/41b15d8a0ad6a81323b598bfb19cede9.png',
#    'size': 'extralarge'}],
#  '@attr': {'rank': '1'}}

# %% [markdown]
# ### 2) Get top albums data
# Store the data extracted above in a dataframe. I am turning all artist names into uppercase to avoid problems when I merge data in the later steps of this project.

# %%
# For loop to store top kpop albums in a dataframme
top_albums_json = top_albums_r.json()['albums']['album']

d={}
d["artist"]=[]
d["album"]=[]
d["rank"]=[]
for i, val in enumerate(top_albums_json):
    d["artist"].append(val["artist"]["name"])
    d["album"].append(val["name"])
    d["rank"].append(val["@attr"]["rank"])

top_albums = pd.DataFrame(d).head(20)

#create a column with artist name in uppercase
top_albums["artist"] = top_albums["artist"].apply(lambda x: x.upper())

top_albums
# Out:
#                  artist                                   album rank
# 0                   BTS                                Dynamite    1
# 1   TOMORROW X TOGETHER               The Chaos Chapter: FREEZE    2
# 2                J-HOPE                              Hope World    3
# 3                   BTS                             Dark & Wild    4
# 4                  LISA                                  LALISA    5
# 5   TOMORROW X TOGETHER                The Dream Chapter: MAGIC    6
# 6             BLACKPINK                               SQUARE UP    7
# 7            STRAY KIDS                                  NOEASY    8
# 8                 LOONA                                 [12:00]    9
# 9                  ROSÉ                                       R   10
# 10              ENHYPEN                       BORDER : CARNIVAL   11
# 11                  BTS  The Most Beautiful Moment In Life Pt.2   12
# 12           STRAY KIDS                                 GO Live   13
# 13              ENHYPEN                        BORDER : DAY ONE   14
# 14                  NCT                        NCT 2018 EMPATHY   15
# 15            BLACKPINK                              SQUARE ONE   16
# 16                 ITZY                               GUESS WHO   17
# 17               IZ*ONE                                BLOOM*IZ   18
# 18                 K/DA                                 ALL OUT   19
# 19            BLACKPINK                              SQUARE TWO   20

# %% [markdown]
# I am using only the top 20 albums to keep the project simple.
#
# As of December 2021, I can see that a couple of artists have multiple albums performing at the top. Doing a little bit of research, I also learned that some of the top albums were solo projects of the these bands members. For example, BTS has 4 entries in the top 20 and J-Hope is a member of BTS. Same with Blackpink and Rose/Lisa. It seems that these two groups are quite strong in the k-pop scene.
#
# ### 3) Get album info
# Below, I set the parameters to get further album information (basically, playcount, listeners, and track names). I build a for loop that will go line by line and feed artist and album name into the `'method': 'album.getInfo'`.

# %%
# Do a for loop to get album info for each album in top_albums
albuminfo_list = []
for artist, album in zip(top_albums["artist"], top_albums["album"]):
    payload_albuminfo = {'api_key': API_KEY, 'method': 'album.getInfo', 'artist':artist, 'album':album,'format': 'json'}
    albuminfo_list.append(requests.get('https://ws.audioscrobbler.com/2.0/', headers=headers, params=payload_albuminfo).json())
    time.sleep(6)

# %% [markdown]
# Let's check first entry and prepare a loop to store relevant data in a dataframe

# %%
# Data output: check first entry
albuminfo_list[0]["album"]
# Out:
# {'artist': 'BTS',
#  'mbid': '0da3ed2f-392f-4c80-848f-193f38b0d0b3',
#  'tags': {'tag': [{'url': 'https://www.last.fm/tag/pop', 'name': 'pop'},
#    {'url': 'https://www.last.fm/tag/bts', 'name': 'bts'},
#    {'url': 'https://www.last.fm/tag/disco', 'name': 'disco'},
#    {'url': 'https://www.last.fm/tag/kpop', 'name': 'kpop'},
#    {'url': 'https://www.last.fm/tag/funk', 'name': 'funk'}]},
#  'playcount': '28673011',
#  'image': [{'size': 'small',
#    '#text': 'https://lastfm.freetls.fastly.net/i/u/34s/41b15d8a0ad6a81323b598bfb19cede9.jpg'},
#   {'size': 'medium',
#    '#text': 'https://lastfm.freetls.fastly.net/i/u/64s/41b15d8a0ad6a81323b598bfb19cede9.jpg'},
#   {'size': 'large',
#    '#text': 'https://lastfm.freetls.fastly.net/i/u/174s/41b15d8a0ad6a81323b598bfb19cede9.jpg'},
#   {'size': 'extralarge',
#    '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/41b15d8a0ad6a81323b598bfb19cede9.jpg'},
#   {'size': 'mega',
#    '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/41b15d8a0ad6a81323b598bfb19cede9.jpg'},
#   {'size': '',
#    '#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/41b15d8a0ad6a81323b598bfb19cede9.jpg'}],
#  'tracks': {'track': [{'streamable': {'fulltrack': '0', '#text': '0'},
#     'duration': 199,
#     'url': 'https://www.last.fm/music/BTS/Dynamite/Dynamite',
#     'name': 'Dynamite',
#     '@attr': {'rank': 1},
#     'artist': {'url': 'https://www.last.fm/music/BTS',
#      'name': 'BTS',
#      'mbid': '0d79fe8e-ba27-4859-bb8c-2f255f346853'}},
#    {'streamable': {'fulltrack': '0', '#text': '0'},
#     'duration': 198,
#     'url': 'https://www.last.fm/music/BTS/Dynamite/Dynamite+-+Instrumental',
#     'name': 'Dynamite - Instrumental',
#     '@attr': {'rank': 2},
#     'artist': {'url': 'https://www.last.fm/music/BTS',
#      'name': 'BTS',
#      'mbid': '0d79fe8e-ba27-4859-bb8c-2f255f346853'}}]},
#  'url': 'https://www.last.fm/music/BTS/Dynamite',
#  'name': 'Dynamite',
#  'listeners': '248325',
#  'wiki': {'published': '11 Nov 2021, 19:26',
#   'summary': '"Dynamite" is a song (Single) recorded by South Korean boy band BTS, released on August 21, 2020, through Big Hit Entertainment and Sony Music Entertainment. It is the band\'s first song fully recorded in English. The song, written by David Stewart and Jessica Agombar and produced by Stewart, is an upbeat disco-pop song with elements of funk, soul, and bubblegum pop, and takes influence from 1970s music—it features snapping handclaps, echoing synths, and celebratory horns. Dynamite music video is the fastest in YouTube history to cross the 200 million mark, in just four days and twelve hours after release, and <a href="https://www.last.fm/music/BTS/Dynamite">Read more on Last.fm</a>.',
#   'content': '"Dynamite" is a song (Single) recorded by South Korean boy band BTS, released on August 21, 2020, through Big Hit Entertainment and Sony Music Entertainment. It is the band\'s first song fully recorded in English. The song, written by David Stewart and Jessica Agombar and produced by Stewart, is an upbeat disco-pop song with elements of funk, soul, and bubblegum pop, and takes influence from 1970s music—it features snapping handclaps, echoing synths, and celebratory horns.\n\n\nDynamite music video is the fastest in YouTube history to cross the 200 million mark, in just four days and twelve hours after release, and the fastest by a music group to surpass 400 million views, doing so on September 26, 35 days after release. It is the fastest music video by both a group and an Asian act to achieve 500 million views—59 days after release —and the fastest by a Korean artist to cross 600 million views, doing so on November 16 in just under 27 days of its exceeding the former milestone. On December 17, "Dynamite" surpassed 700 million views, achieving the mark in under four months. It became the fastest music video by a Korean group to achieve 800–900 million views, when it crossed the former five months after release in January 2021, and the latter 40 days later. The video is BTS\' fastest to reach 1 billion views—on April 12, 2021 in just under eight months—and their third, after "DNA" and "Boy with Luv". It is also the fastest by a Korean artist to do so.\n\n\nInitially a standalone single, "Dynamite" was later included on BTS\' fifth Korean-language album, Be (2020), released on November 20. <a href="https://www.last.fm/music/BTS/Dynamite">Read more on Last.fm</a>. User-contributed text is available under the Creative Commons By-SA License; additional terms may apply.'}}

# %%
# For loop to store the data into a dataframe
x = {}
x["artist"]=[]
x["name"]=[]
x["playcount"]=[]
x["listeners"]=[]
x["published"]=[]
x["jpg"]=[]
x["numtracks"]=[]
x["trackname"]=[]
x["tracksdur"]=[]

for album in albuminfo_list:
    x["artist"].append(album["album"]["artist"])
    x["name"].append(album["album"]["name"])
    x["playcount"].append(album["album"]["playcount"])
    x["listeners"].append(album["album"]["listeners"])
    x["jpg"].append(album["album"]["image"][2]["#text"])
    try:
        x["published"].append(album["album"]["wiki"]["published"])
    except:
        x["published"].append("NA")
    try:
        x["numtracks"].append(len(album["album"]["tracks"]["track"]))
    except:
        x["numtracks"].append(0)
    try:
        x["trackname"].append([t["name"] for t in album["album"]["tracks"]["track"]])
    except:
        x["trackname"].append(["NA"])
    try:
        x["tracksdur"].append([t["duration"] for t in album["album"]["tracks"]["track"]])
    except:
        x["tracksdur"].append(["0"])

# Store track data into a dataframe and bring rank column from top_albums 
albuminfo = pd.DataFrame(x)
albuminfo = albuminfo.merge(right=top_albums["rank"], left_index=True, right_index=True)

# %%
# Check albuminfo data
albuminfo
# Out:
#                  artist                                    name playcount  \
# 0                   BTS                                Dynamite  28673011
# 1   TOMORROW X TOGETHER               The Chaos Chapter: FREEZE  24279001
# 2                j-hope                              Hope World  23430617
# 3                   BTS                             DARK & WILD  16051931
# 4                  Lisa                                  LALISA  10477044
# 5   TOMORROW X TOGETHER                The Dream Chapter: MAGIC  10802108
# 6             BLACKPINK                               SQUARE UP  10644536
# 7            Stray Kids                                  NOEASY   9516958
# 8                 Loona                                 [12:00]   8706683
# 9                  Rosé                                       R   8510730
# 10              ENHYPEN                       BORDER : CARNIVAL   8359018
# 11                  BTS  The Most Beautiful Moment In Life Pt.2   8521086
# 12           Stray Kids                                 GO Live   7930601
# 13              ENHYPEN                        BORDER : DAY ONE   6783388
# 14                  NCT                        NCT 2018 EMPATHY   6431069
# 15            BLACKPINK                              SQUARE ONE   6143917
# 16                 ITZY                               GUESS WHO   5454995
# 17               IZ*ONE                                BLOOM*IZ   5326176
# 18                 K/DA                                 ALL OUT   5115044
# 19            BLACKPINK                              SQUARE TWO   5433989
#
#    listeners           published  \
# 0     248325  11 Nov 2021, 19:26
# 1     166105  11 Nov 2021, 13:17
# 2     195267  09 Sep 2021, 19:49
# 3     200195  10 Oct 2021, 21:08
# 4     230773  09 Sep 2021, 18:54
# 5     160810  11 Nov 2019, 20:29
# 6     292527  07 Jul 2021, 16:47
# 7      93995  12 Dec 2021, 21:38
# 8     149945  03 Mar 2021, 15:41
# 9     178075  09 Sep 2021, 16:35
# 10    149207  10 Oct 2021, 23:29
# 11    185287                  NA
# 12    157089  11 Nov 2020, 12:26
# 13    120276  10 Oct 2021, 23:26
# 14    149895  03 Mar 2018, 02:22
# 15    253888  12 Dec 2020, 21:48
# 16    144705  05 May 2021, 22:22
# 17     92662  02 Feb 2020, 14:43
# 18    140332  01 Jan 2021, 15:45
# 19    211087  12 Dec 2020, 21:49
#
#                                                   jpg  numtracks  \
# 0   https://lastfm.freetls.fastly.net/i/u/174s/41b...          2
# 1   https://lastfm.freetls.fastly.net/i/u/174s/d5e...          8
# 2   https://lastfm.freetls.fastly.net/i/u/174s/57b...          7
# 3   https://lastfm.freetls.fastly.net/i/u/174s/67f...         14
# 4   https://lastfm.freetls.fastly.net/i/u/174s/386...          2
# 5   https://lastfm.freetls.fastly.net/i/u/174s/ac8...          8
# 6   https://lastfm.freetls.fastly.net/i/u/174s/f18...          5
# 7   https://lastfm.freetls.fastly.net/i/u/174s/8f3...         14
# 8   https://lastfm.freetls.fastly.net/i/u/174s/148...          8
# 9   https://lastfm.freetls.fastly.net/i/u/174s/3e4...          0
# 10  https://lastfm.freetls.fastly.net/i/u/174s/450...          6
# 11  https://lastfm.freetls.fastly.net/i/u/174s/d28...          0
# 12  https://lastfm.freetls.fastly.net/i/u/174s/83d...          0
# 13  https://lastfm.freetls.fastly.net/i/u/174s/3db...          6
# 14  https://lastfm.freetls.fastly.net/i/u/174s/a84...         14
# 15  https://lastfm.freetls.fastly.net/i/u/174s/fad...          2
# 16  https://lastfm.freetls.fastly.net/i/u/174s/95a...          6
# 17  https://lastfm.freetls.fastly.net/i/u/174s/c76...          6
# 18  https://lastfm.freetls.fastly.net/i/u/174s/335...          5
# 19  https://lastfm.freetls.fastly.net/i/u/174s/f91...          5
#
#                                             trackname  \
# 0                 [Dynamite, Dynamite - Instrumental]
# 1   [ANTI-ROMANTIC, 0X1=LOVESONG (I Know I Love Yo...
# 2   [Hope World, P.O.P (Piece Of Peace) pt.1, 백일몽 ...
# 3   [Intro: What Am I to You, Danger, War of Hormo...
# 4                                     [LALISA, MONEY]
# 5   [New Rules, 9 and Three Quarters (Run Away), R...
# 6   [뚜두뚜두 (DDU-DU DDU-DU), Forever Young, REALLY, ...
# 7   [CHEESE, Thunderous, DOMINO, Ssick, The View, ...
# 8   [12:00, Why Not?, Voice, Fall Again, Universe,...
# 9                                                [NA]
# 10  [Intro : The Invitation, Drunk-Dazed, FEVER, N...
# 11                                               [NA]
# 12                                               [NA]
# 13  [Intro : Walk the Line, Given-Taken, Let Me In...
# 14  [INTRO: Neo Got My Back, BOSS, Baby Don't Stop...
# 15                               [WHISTLE, BOOMBAYAH]
# 16  [In the morning, Sorry Not Sorry, KIDDING ME, ...
# 17                                               [NA]
# 18  [THE BADDEST, MORE, VILLAIN, DRUM GO DUM, I'LL...
# 19  [불장난, STAY, WHISTLE (Acoustic Ver.), 휘파람, BOOM...
#
#                                             tracksdur rank
# 0                                          [199, 198]    1
# 1            [215, 202, 160, 203, 186, 186, 195, 195]    2
# 2                   [204, 181, 228, 89, 229, 197, 90]    3
# 3   [165, 245, 266, 257, 254, 265, None, 41, 234, ...    4
# 4                                          [200, 168]    5
# 5            [175, 211, 214, 193, 230, 193, 217, 232]    6
# 6                           [215, 237, 197, 216, 213]    7
# 7   [182, 183, 198, 190, 201, 177, 209, 209, 215, ...    8
# 8             [73, 205, 198, 215, 214, 182, 162, 198]    9
# 9                                                 [0]   10
# 10                      [130, 193, 172, 181, 183, 94]   11
# 11                                                [0]   12
# 12                                                [0]   13
# 13                     [108, 183, 191, 194, 144, 115]   14
# 14  [117, 210, 183, 207, 189, 196, 197, 250, 214, ...   15
# 15                                         [213, 242]   16
# 16                     [172, 190, 214, 203, 139, 219]   17
# 17                                                [0]   18
# 18                          [162, 217, 199, 200, 198]   19
# 19                          [197, 230, 212, 211, 242]   20

# %% [markdown]
# Data above shows all k-pop albums with columns containing track names and track duration. Before proceeding to the next step, I will save the jpg files in my work folder. These are album jackets for each top album and I will use then in the dashboard.

# %%
# loop through every jpg row and save the jpg file
# I use generic file names so that it is easy to update when it is linked to the dashboard
import urllib.request

for idx, url in enumerate(albuminfo["jpg"]):
    filename = albuminfo.loc[idx,"rank"].zfill(2)+"_albumrank"+url[-4:]
    urllib.request.urlretrieve(url, filename)
    print("saved "+filename)
# Out:
# saved 01_albumrank.jpg
# saved 02_albumrank.jpg
# saved 03_albumrank.jpg
# saved 04_albumrank.png
# saved 05_albumrank.jpg
# saved 06_albumrank.jpg
# saved 07_albumrank.jpg
# saved 08_albumrank.png
# saved 09_albumrank.png
# saved 10_albumrank.jpg
# saved 11_albumrank.jpg
# saved 12_albumrank.jpg
# saved 13_albumrank.jpg
# saved 14_albumrank.jpg
# saved 15_albumrank.jpg
# saved 16_albumrank.png
# saved 17_albumrank.png
# saved 18_albumrank.jpg
# saved 19_albumrank.jpg
# saved 20_albumrank.png

# %% [markdown]
# ### 4) Process track names and duration
# Note how `trackname` and `tracksdur` are actually lists inside rows. As the name suggests, `trackname`  is the name of track and `tracksdur` is its duration in seconds. Each album has multiple tracks and these need to be transposed so that one track fits inside a single row. In the next couple of cells, I will perform this task by transposing both variables and merging those back to albuminfo.

# %%
# transform trackname column into a list and put it back in a dataframe.
# note how now I have a dataframe where each element populates a cell.
tracknametbl = pd.DataFrame(albuminfo["trackname"].tolist())
tracknametbl
# Out:
#                          0                                               1   \
# 0                  Dynamite                         Dynamite - Instrumental
# 1             ANTI-ROMANTIC  0X1=LOVESONG (I Know I Love You) (feat. Seori)
# 2                Hope World                     P.O.P (Piece Of Peace) pt.1
# 3   Intro: What Am I to You                                          Danger
# 4                    LALISA                                           MONEY
# 5                 New Rules                 9 and Three Quarters (Run Away)
# 6      뚜두뚜두 (DDU-DU DDU-DU)                                   Forever Young
# 7                    CHEESE                                      Thunderous
# 8                     12:00                                        Why Not?
# 9                        NA                                            None
# 10   Intro : The Invitation                                     Drunk-Dazed
# 11                       NA                                            None
# 12                       NA                                            None
# 13    Intro : Walk the Line                                     Given-Taken
# 14   INTRO: Neo Got My Back                                            BOSS
# 15                  WHISTLE                                       BOOMBAYAH
# 16           In the morning                                 Sorry Not Sorry
# 17                       NA                                            None
# 18              THE BADDEST                                            MORE
# 19                      불장난                                            STAY
#
#                          2               3   \
# 0                      None            None
# 1                     MAGIC             소악행
# 2            백일몽 (Daydream)       Base Line
# 3            War of Hormone   Hip Hop Phile
# 4                      None            None
# 5            Roller Coaster    Poppin' Star
# 6                    REALLY     SEE U LATER
# 7                    DOMINO           Ssick
# 8                     Voice      Fall Again
# 9                      None            None
# 10                    FEVER    Not For Sale
# 11                     None            None
# 12                     None            None
# 13      Let Me In (20 CUBE)       10 Months
# 14          Baby Don't Stop              GO
# 15                     None            None
# 16               KIDDING ME  Wild Wild West
# 17                     None            None
# 18                  VILLAIN     DRUM GO DUM
# 19  WHISTLE (Acoustic Ver.)             휘파람
#
#                                         4                       5   \
# 0                                     None                    None
# 1                                  밸런스 게임)                No Rules
# 2                            항상 (HANGSANG)                Airplane
# 3                              Let Me Know                    Rain
# 4                                     None                    None
# 5   Can't We Just Leave The Monster Alive?            Magic Island
# 6                                    마지막처럼                    None
# 7                                 The View       Sorry, I Love You
# 8                                 Universe             Hide & Seek
# 9                                     None                    None
# 10                                Mixed Up    Outro : The Wormhole
# 11                                    None                    None
# 12                                    None                    None
# 13                                 FLICKER  Outro : Cross the Line
# 14                                   TOUCH                YESTODAY
# 15                                    None                    None
# 16                                  SHOOT!            TENNIS (0:0)
# 17                                    None                    None
# 18                           I'LL SHOW YOU                    None
# 19                               BOOMBAYAH                    None
#
#                                               6   \
# 0                                           None
# 1                                       디어 스푸트니크
# 2                              Blue Side (Outro)
# 3   BTS Cypher PT.3 : Killer [feat. Supreme Boi]
# 4                                           None
# 5                                           20cm
# 6                                           None
# 7                                     Silent Cry
# 8                                          OOPS!
# 9                                           None
# 10                                          None
# 11                                          None
# 12                                          None
# 13                                          None
# 14                                Black on Black
# 15                                          None
# 16                                          None
# 17                                          None
# 18                                          None
# 19                                          None
#
#                                     7                                   8   \
# 0                                 None                                None
# 1                                Frost                                None
# 2                                 None                                None
# 3   Interlude : What Are You Doing Now  Could You Turn Off Your Cell Phone
# 4                                 None                                None
# 5                       Angel Or Devil                                None
# 6                                 None                                None
# 7                        Secret Secret                           Star Lost
# 8                                 Star                                None
# 9                                 None                                None
# 10                                None                                None
# 11                                None                                None
# 12                                None                                None
# 13                                None                                None
# 14                      텐데… (Timeless)            일곱 번째 감각 (The 7th Sense)
# 15                                None                                None
# 16                                None                                None
# 17                                None                                None
# 18                                None                                None
# 19                                None                                None
#
#                                  9                                    10  \
# 0                              None                                 None
# 1                              None                                 None
# 2                              None                                 None
# 3                       Embarrassed                          24/7=heaven
# 4                              None                                 None
# 5                              None                                 None
# 6                              None                                 None
# 7   Red Lights (Bang Chan, Hyunjin)  Surfin' (Lee Know, Changbin, Felix)
# 8                              None                                 None
# 9                              None                                 None
# 10                             None                                 None
# 11                             None                                 None
# 12                             None                                 None
# 13                             None                                 None
# 14                      Without You           Without You (Chinese Ver.)
# 15                             None                                 None
# 16                             None                                 None
# 17                             None                                 None
# 18                             None                                 None
# 19                             None                                 None
#
#                                 11             12  \
# 0                             None           None
# 1                             None           None
# 2                             None           None
# 3                        Look Here      So 4 more
# 4                             None           None
# 5                             None           None
# 6                             None           None
# 7   Gone Away (Han, Seungmin, I.N)       WOLFGANG
# 8                             None           None
# 9                             None           None
# 10                            None           None
# 11                            None           None
# 12                            None           None
# 13                            None           None
# 14    梦中梦 (몽중몽 ; Dream In A Dream)  OUTRO: VISION
# 15                            None           None
# 16                            None           None
# 17                            None           None
# 18                            None           None
# 19                            None           None
#
#                                       13
# 0                                   None
# 1                                   None
# 2                                   None
# 3   Outro : Do You Think It Makes Sense?
# 4                                   None
# 5                                   None
# 6                                   None
# 7                           Mixtape : OH
# 8                                   None
# 9                                   None
# 10                                  None
# 11                                  None
# 12                                  None
# 13                                  None
# 14              YESTODAY (Extended Ver.)
# 15                                  None
# 16                                  None
# 17                                  None
# 18                                  None
# 19                                  None

# %%
# build a temporary dataframe "t" and merge that with dataframe of track names 
t = albuminfo.drop(["trackname", "tracksdur"], axis=1)
albuminfo_1 = t.merge(right=tracknametbl, how='left', left_index=True, right_index=True)

# use melt to unpivot track names
albuminfo_1 = albuminfo_1.melt(id_vars=t.columns, value_name='trackname_melt')

# check result
albuminfo_1
# Out:
#                   artist                       name playcount listeners  \
# 0                    BTS                   Dynamite  28673011    248325
# 1    TOMORROW X TOGETHER  The Chaos Chapter: FREEZE  24279001    166105
# 2                 j-hope                 Hope World  23430617    195267
# 3                    BTS                DARK & WILD  16051931    200195
# 4                   Lisa                     LALISA  10477044    230773
# ..                   ...                        ...       ...       ...
# 275            BLACKPINK                 SQUARE ONE   6143917    253888
# 276                 ITZY                  GUESS WHO   5454995    144705
# 277               IZ*ONE                   BLOOM*IZ   5326176     92662
# 278                 K/DA                    ALL OUT   5115044    140332
# 279            BLACKPINK                 SQUARE TWO   5433989    211087
#
#               published                                                jpg  \
# 0    11 Nov 2021, 19:26  https://lastfm.freetls.fastly.net/i/u/174s/41b...
# 1    11 Nov 2021, 13:17  https://lastfm.freetls.fastly.net/i/u/174s/d5e...
# 2    09 Sep 2021, 19:49  https://lastfm.freetls.fastly.net/i/u/174s/57b...
# 3    10 Oct 2021, 21:08  https://lastfm.freetls.fastly.net/i/u/174s/67f...
# 4    09 Sep 2021, 18:54  https://lastfm.freetls.fastly.net/i/u/174s/386...
# ..                  ...                                                ...
# 275  12 Dec 2020, 21:48  https://lastfm.freetls.fastly.net/i/u/174s/fad...
# 276  05 May 2021, 22:22  https://lastfm.freetls.fastly.net/i/u/174s/95a...
# 277  02 Feb 2020, 14:43  https://lastfm.freetls.fastly.net/i/u/174s/c76...
# 278  01 Jan 2021, 15:45  https://lastfm.freetls.fastly.net/i/u/174s/335...
# 279  12 Dec 2020, 21:49  https://lastfm.freetls.fastly.net/i/u/174s/f91...
#
#      numtracks rank variable           trackname_melt
# 0            2    1        0                 Dynamite
# 1            8    2        0            ANTI-ROMANTIC
# 2            7    3        0               Hope World
# 3           14    4        0  Intro: What Am I to You
# 4            2    5        0                   LALISA
# ..         ...  ...      ...                      ...
# 275          2   16       13                     None
# 276          6   17       13                     None
# 277          6   18       13                     None
# 278          5   19       13                     None
# 279          5   20       13                     None
#
# [280 rows x 10 columns]

# %% [markdown]
# Now all track names have its own row and duplicates were created for all data associated with album data. See the case for this group called "ITZY":

# %%
albuminfo_1[albuminfo_1["artist"]=="ITZY"]
# Out:
#     artist       name playcount listeners           published  \
# 16    ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
# 36    ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
# 56    ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
# 76    ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
# 96    ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
# 116   ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
# 136   ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
# 156   ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
# 176   ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
# 196   ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
# 216   ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
# 236   ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
# 256   ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
# 276   ITZY  GUESS WHO   5454995    144705  05 May 2021, 22:22
#
#                                                    jpg  numtracks rank  \
# 16   https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
# 36   https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
# 56   https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
# 76   https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
# 96   https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
# 116  https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
# 136  https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
# 156  https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
# 176  https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
# 196  https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
# 216  https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
# 236  https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
# 256  https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
# 276  https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17
#
#     variable   trackname_melt
# 16         0   In the morning
# 36         1  Sorry Not Sorry
# 56         2       KIDDING ME
# 76         3   Wild Wild West
# 96         4           SHOOT!
# 116        5     TENNIS (0:0)
# 136        6             None
# 156        7             None
# 176        8             None
# 196        9             None
# 216       10             None
# 236       11             None
# 256       12             None
# 276       13             None

# %% [markdown]
# There are several rows with None and that was totally expected. I will remove those in later steps.
#
# Below, I do exactly the same thing for `tracksdur` and merge the results to get a single table containing track names and track duration.

# %%
# I do exact the same procedure for tracksdur
# will skip commentary
tracksdurtbl = pd.DataFrame(albuminfo["tracksdur"].tolist())
albuminfo_2 = t.merge(right=tracksdurtbl, how='left', left_index=True, right_index=True)
albuminfo_2 = albuminfo_2.melt(id_vars=t.columns, value_name='tracksdur_melt')
albuminfo_2

# now let's bring unpivoted tracksdur to the table with unpivoted track names.
albuminfo_3 = albuminfo_1.merge(albuminfo_2["tracksdur_melt"], left_index=True, right_index=True)
albuminfo_3
# Out:
#                   artist                       name playcount listeners  \
# 0                    BTS                   Dynamite  28673011    248325
# 1    TOMORROW X TOGETHER  The Chaos Chapter: FREEZE  24279001    166105
# 2                 j-hope                 Hope World  23430617    195267
# 3                    BTS                DARK & WILD  16051931    200195
# 4                   Lisa                     LALISA  10477044    230773
# ..                   ...                        ...       ...       ...
# 275            BLACKPINK                 SQUARE ONE   6143917    253888
# 276                 ITZY                  GUESS WHO   5454995    144705
# 277               IZ*ONE                   BLOOM*IZ   5326176     92662
# 278                 K/DA                    ALL OUT   5115044    140332
# 279            BLACKPINK                 SQUARE TWO   5433989    211087
#
#               published                                                jpg  \
# 0    11 Nov 2021, 19:26  https://lastfm.freetls.fastly.net/i/u/174s/41b...
# 1    11 Nov 2021, 13:17  https://lastfm.freetls.fastly.net/i/u/174s/d5e...
# 2    09 Sep 2021, 19:49  https://lastfm.freetls.fastly.net/i/u/174s/57b...
# 3    10 Oct 2021, 21:08  https://lastfm.freetls.fastly.net/i/u/174s/67f...
# 4    09 Sep 2021, 18:54  https://lastfm.freetls.fastly.net/i/u/174s/386...
# ..                  ...                                                ...
# 275  12 Dec 2020, 21:48  https://lastfm.freetls.fastly.net/i/u/174s/fad...
# 276  05 May 2021, 22:22  https://lastfm.freetls.fastly.net/i/u/174s/95a...
# 277  02 Feb 2020, 14:43  https://lastfm.freetls.fastly.net/i/u/174s/c76...
# 278  01 Jan 2021, 15:45  https://lastfm.freetls.fastly.net/i/u/174s/335...
# 279  12 Dec 2020, 21:49  https://lastfm.freetls.fastly.net/i/u/174s/f91...
#
#      numtracks rank variable           trackname_melt tracksdur_melt
# 0            2    1        0                 Dynamite            199
# 1            8    2        0            ANTI-ROMANTIC            215
# 2            7    3        0               Hope World            204
# 3           14    4        0  Intro: What Am I to You            165
# 4            2    5        0                   LALISA            200
# ..         ...  ...      ...                      ...            ...
# 275          2   16       13                     None            NaN
# 276          6   17       13                     None            NaN
# 277          6   18       13                     None            NaN
# 278          5   19       13                     None            NaN
# 279          5   20       13                     None            NaN
#
# [280 rows x 11 columns]

# %% [markdown]
# Now I proceed to do some renaming and remove null rows.

# %%
# rename "variable" to trackno (tracknumber) and add 1
albuminfo_melt = albuminfo_3.rename(columns={"variable":"trackno"})
albuminfo_melt["trackno"]=albuminfo_melt["trackno"]+1
albuminfo_melt = albuminfo_melt.dropna()

# show the data
albuminfo_melt = albuminfo_melt.reset_index(drop=True)
albuminfo_melt
# Out:
#                   artist                       name playcount listeners  \
# 0                    BTS                   Dynamite  28673011    248325
# 1    TOMORROW X TOGETHER  The Chaos Chapter: FREEZE  24279001    166105
# 2                 j-hope                 Hope World  23430617    195267
# 3                    BTS                DARK & WILD  16051931    200195
# 4                   Lisa                     LALISA  10477044    230773
# ..                   ...                        ...       ...       ...
# 109           Stray Kids                     NOEASY   9516958     93995
# 110                  NCT           NCT 2018 EMPATHY   6431069    149895
# 111                  BTS                DARK & WILD  16051931    200195
# 112           Stray Kids                     NOEASY   9516958     93995
# 113                  NCT           NCT 2018 EMPATHY   6431069    149895
#
#               published                                                jpg  \
# 0    11 Nov 2021, 19:26  https://lastfm.freetls.fastly.net/i/u/174s/41b...
# 1    11 Nov 2021, 13:17  https://lastfm.freetls.fastly.net/i/u/174s/d5e...
# 2    09 Sep 2021, 19:49  https://lastfm.freetls.fastly.net/i/u/174s/57b...
# 3    10 Oct 2021, 21:08  https://lastfm.freetls.fastly.net/i/u/174s/67f...
# 4    09 Sep 2021, 18:54  https://lastfm.freetls.fastly.net/i/u/174s/386...
# ..                  ...                                                ...
# 109  12 Dec 2021, 21:38  https://lastfm.freetls.fastly.net/i/u/174s/8f3...
# 110  03 Mar 2018, 02:22  https://lastfm.freetls.fastly.net/i/u/174s/a84...
# 111  10 Oct 2021, 21:08  https://lastfm.freetls.fastly.net/i/u/174s/67f...
# 112  12 Dec 2021, 21:38  https://lastfm.freetls.fastly.net/i/u/174s/8f3...
# 113  03 Mar 2018, 02:22  https://lastfm.freetls.fastly.net/i/u/174s/a84...
#
#      numtracks rank trackno                        trackname_melt  \
# 0            2    1       1                              Dynamite
# 1            8    2       1                         ANTI-ROMANTIC
# 2            7    3       1                            Hope World
# 3           14    4       1               Intro: What Am I to You
# 4            2    5       1                                LALISA
# ..         ...  ...     ...                                   ...
# 109         14    8      13                              WOLFGANG
# 110         14   15      13                         OUTRO: VISION
# 111         14    4      14  Outro : Do You Think It Makes Sense?
# 112         14    8      14                          Mixtape : OH
# 113         14   15      14              YESTODAY (Extended Ver.)
#
#     tracksdur_melt
# 0              199
# 1              215
# 2              204
# 3              165
# 4              200
# ..             ...
# 109          192.0
# 110           57.0
# 111          172.0
# 112          212.0
# 113          227.0
#
# [114 rows x 11 columns]

# %% [markdown]
# ### 5) Get more track data (= track playcount)
# The data is already looking quite good, but it is missing one important variable: **track playcount**. The playcount data that I currently have is **album playcount** which is not good enough if I want to analyze track as well. LastFM's `'method': 'album.getInfo'` does not store a lot of track information, so I need to set a new request using `'method':'track.getInfo'`.
#
# The code is quite similar to what I have already written above. So I will skip commentary and get to the final data to avoid being too repetitive.

# %%
from tqdm.notebook import tqdm
bar = tqdm(total = albuminfo_melt.shape[0])

trackinfo_list = []
for artist, track in zip(albuminfo_melt["artist"], albuminfo_melt["trackname_melt"]):
    payload_trackinfo = {'api_key': API_KEY, 'method': 'track.getInfo', 'artist':artist, 'track':track,'format': 'json'}
    trackinfo_list.append(requests.get('https://ws.audioscrobbler.com/2.0/', headers=headers, params=payload_trackinfo).json())
    bar.update(1)
    time.sleep(3)
# Out:
#   0%|          | 0/114 [00:00<?, ?it/s]

# %%
trackinfo_list[0]["track"]
# Out:
# {'name': 'Dynamite',
#  'url': 'https://www.last.fm/music/BTS/_/Dynamite',
#  'duration': '199000',
#  'streamable': {'#text': '0', 'fulltrack': '0'},
#  'listeners': '435982',
#  'playcount': '80642441',
#  'artist': {'name': 'BTS',
#   'mbid': '0d79fe8e-ba27-4859-bb8c-2f255f346853',
#   'url': 'https://www.last.fm/music/BTS'},
#  'album': {'artist': 'BTS',
#   'title': 'Dynamite (Extended)',
#   'url': 'https://www.last.fm/music/BTS/Dynamite+(Extended)',
#   'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/0e41a35afb8e2ad81aca9621d420a33f.png',
#     'size': 'small'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/0e41a35afb8e2ad81aca9621d420a33f.png',
#     'size': 'medium'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/0e41a35afb8e2ad81aca9621d420a33f.png',
#     'size': 'large'},
#    {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/0e41a35afb8e2ad81aca9621d420a33f.png',
#     'size': 'extralarge'}]},
#  'toptags': {'tag': [{'name': 'pop', 'url': 'https://www.last.fm/tag/pop'},
#    {'name': 'Disco', 'url': 'https://www.last.fm/tag/Disco'},
#    {'name': 'bts', 'url': 'https://www.last.fm/tag/bts'},
#    {'name': 'k-pop', 'url': 'https://www.last.fm/tag/k-pop'},
#    {'name': 'Kpop', 'url': 'https://www.last.fm/tag/Kpop'}]},
#  'wiki': {'published': '21 Aug 2020, 23:39',
#   'summary': '"Dynamite" is a song by South Korean boy band BTS. It was released on August 21, 2020, through Big Hit and Sony Music as the group\'s first song fully recorded in English. \n\nThe accompanying music video broke the world record for receiving the most views within 24 hours on YouTube, garnering 101.1 million views. According to YouTube, it also broke the record for a video premiere with 3 million concurrent viewers. The song debut at #1 on the Billboard Hot100 chart. <a href="http://www.last.fm/music/BTS/_/Dynamite">Read more on Last.fm</a>.',
#   'content': '"Dynamite" is a song by South Korean boy band BTS. It was released on August 21, 2020, through Big Hit and Sony Music as the group\'s first song fully recorded in English. \n\nThe accompanying music video broke the world record for receiving the most views within 24 hours on YouTube, garnering 101.1 million views. According to YouTube, it also broke the record for a video premiere with 3 million concurrent viewers. The song debut at #1 on the Billboard Hot100 chart.\n\nThe song was later included in their seventh mini-album, Be.\n\nDynamite by BTS (방탄소년단) Apple Music\n\nBTS  (방탄소년단)  Last.FM Page - Korean Name:  (https://www.last.fm/music/방탄소년단)\nBTS  (방탄소년단)  Last.FM Page - English Name: (https://www.last.fm/music/BTS)\nTrack (Apple Music): (https://music.apple.com/us/album/dynamite/1529518691?i=1529518695) <a href="http://www.last.fm/music/BTS/_/Dynamite">Read more on Last.fm</a>. User-contributed text is available under the Creative Commons By-SA License; additional terms may apply.'}}

# %%
name=[]
album=[]
artist=[]
playcount=[]
listeners=[]

for t in range(len(trackinfo_list)):
    try:
        name.append(trackinfo_list[t]["track"]["name"])
    except:
        name.append("NA")        
    try:
        album.append(trackinfo_list[t]["track"]["album"]["title"])
    except:
        album.append("NA")
    try:
        artist.append(trackinfo_list[t]["track"]["artist"]["name"])
    except:
        artist.append("NA")
    try:
        playcount.append(trackinfo_list[t]["track"]["playcount"])
    except:
        playcount.append(0)
    try:
        listeners.append(trackinfo_list[t]["track"]["listeners"])
    except:
        listeners.append(0)

trackinfo_df = pd.DataFrame(dict(name=name,album=album, artist=artist, playcount=playcount, listeners=listeners))
trackinfo_df
# Out:
#                                      name                      album  \
# 0                                Dynamite        Dynamite (Extended)
# 1                           ANTI-ROMANTIC  The Chaos Chapter: FREEZE
# 2                              Hope World                         NA
# 3                 Intro: What Am I to You                DARK & WILD
# 4                                  LALISA                     LALISA
# ..                                    ...                        ...
# 109                              WOLFGANG                         NA
# 110                         OUTRO: VISION           NCT 2018 EMPATHY
# 111  Outro : Do You Think It Makes Sense?                  DARK&WILD
# 112                          Mixtape : OH                         NA
# 113              YESTODAY (Extended Ver.)                         NA
#
#                   artist playcount listeners
# 0                    BTS  80642441    435982
# 1    TOMORROW X TOGETHER   3867105    136965
# 2                 J-Hope   3106115    118107
# 3                    BTS    776556     66698
# 4                   Lisa   5342514    138270
# ..                   ...       ...       ...
# 109           STRAY KIDS    962894     40779
# 110                  NCT     95244     13050
# 111                  BTS     29134      3661
# 112           STRAY KIDS   1092738     51049
# 113                  NCT      1463        78
#
# [114 rows x 5 columns]

# %%
albuminfo_data = albuminfo_melt.merge(right=trackinfo_df, left_index=True, right_index=True)
albuminfo_data.head(20)
# Out:
#                artist_x                                  name_x playcount_x  \
# 0                   BTS                                Dynamite    28673011
# 1   TOMORROW X TOGETHER               The Chaos Chapter: FREEZE    24279001
# 2                j-hope                              Hope World    23430617
# 3                   BTS                             DARK & WILD    16051931
# 4                  Lisa                                  LALISA    10477044
# 5   TOMORROW X TOGETHER                The Dream Chapter: MAGIC    10802108
# 6             BLACKPINK                               SQUARE UP    10644536
# 7            Stray Kids                                  NOEASY     9516958
# 8                 Loona                                 [12:00]     8706683
# 9                  Rosé                                       R     8510730
# 10              ENHYPEN                       BORDER : CARNIVAL     8359018
# 11                  BTS  The Most Beautiful Moment In Life Pt.2     8521086
# 12           Stray Kids                                 GO Live     7930601
# 13              ENHYPEN                        BORDER : DAY ONE     6783388
# 14                  NCT                        NCT 2018 EMPATHY     6431069
# 15            BLACKPINK                              SQUARE ONE     6143917
# 16                 ITZY                               GUESS WHO     5454995
# 17               IZ*ONE                                BLOOM*IZ     5326176
# 18                 K/DA                                 ALL OUT     5115044
# 19            BLACKPINK                              SQUARE TWO     5433989
#
#    listeners_x           published  \
# 0       248325  11 Nov 2021, 19:26
# 1       166105  11 Nov 2021, 13:17
# 2       195267  09 Sep 2021, 19:49
# 3       200195  10 Oct 2021, 21:08
# 4       230773  09 Sep 2021, 18:54
# 5       160810  11 Nov 2019, 20:29
# 6       292527  07 Jul 2021, 16:47
# 7        93995  12 Dec 2021, 21:38
# 8       149945  03 Mar 2021, 15:41
# 9       178075  09 Sep 2021, 16:35
# 10      149207  10 Oct 2021, 23:29
# 11      185287                  NA
# 12      157089  11 Nov 2020, 12:26
# 13      120276  10 Oct 2021, 23:26
# 14      149895  03 Mar 2018, 02:22
# 15      253888  12 Dec 2020, 21:48
# 16      144705  05 May 2021, 22:22
# 17       92662  02 Feb 2020, 14:43
# 18      140332  01 Jan 2021, 15:45
# 19      211087  12 Dec 2020, 21:49
#
#                                                   jpg  numtracks rank trackno  \
# 0   https://lastfm.freetls.fastly.net/i/u/174s/41b...          2    1       1
# 1   https://lastfm.freetls.fastly.net/i/u/174s/d5e...          8    2       1
# 2   https://lastfm.freetls.fastly.net/i/u/174s/57b...          7    3       1
# 3   https://lastfm.freetls.fastly.net/i/u/174s/67f...         14    4       1
# 4   https://lastfm.freetls.fastly.net/i/u/174s/386...          2    5       1
# 5   https://lastfm.freetls.fastly.net/i/u/174s/ac8...          8    6       1
# 6   https://lastfm.freetls.fastly.net/i/u/174s/f18...          5    7       1
# 7   https://lastfm.freetls.fastly.net/i/u/174s/8f3...         14    8       1
# 8   https://lastfm.freetls.fastly.net/i/u/174s/148...          8    9       1
# 9   https://lastfm.freetls.fastly.net/i/u/174s/3e4...          0   10       1
# 10  https://lastfm.freetls.fastly.net/i/u/174s/450...          6   11       1
# 11  https://lastfm.freetls.fastly.net/i/u/174s/d28...          0   12       1
# 12  https://lastfm.freetls.fastly.net/i/u/174s/83d...          0   13       1
# 13  https://lastfm.freetls.fastly.net/i/u/174s/3db...          6   14       1
# 14  https://lastfm.freetls.fastly.net/i/u/174s/a84...         14   15       1
# 15  https://lastfm.freetls.fastly.net/i/u/174s/fad...          2   16       1
# 16  https://lastfm.freetls.fastly.net/i/u/174s/95a...          6   17       1
# 17  https://lastfm.freetls.fastly.net/i/u/174s/c76...          6   18       1
# 18  https://lastfm.freetls.fastly.net/i/u/174s/335...          5   19       1
# 19  https://lastfm.freetls.fastly.net/i/u/174s/f91...          5   20       1
#
#              trackname_melt tracksdur_melt                   name_y  \
# 0                  Dynamite            199                 Dynamite
# 1             ANTI-ROMANTIC            215            ANTI-ROMANTIC
# 2                Hope World            204               Hope World
# 3   Intro: What Am I to You            165  Intro: What Am I to You
# 4                    LALISA            200                   LALISA
# 5                 New Rules            175                New Rules
# 6      뚜두뚜두 (DDU-DU DDU-DU)            215     뚜두뚜두 (DDU-DU DDU-DU)
# 7                    CHEESE            182                   CHEESE
# 8                     12:00             73                    12:00
# 9                        NA              0                       NA
# 10   Intro : The Invitation            130   Intro : The Invitation
# 11                       NA              0                       NA
# 12                       NA              0                       NA
# 13    Intro : Walk the Line            108    Intro : Walk the Line
# 14   INTRO: Neo Got My Back            117   Intro: Neo Got My Back
# 15                  WHISTLE            213                  WHISTLE
# 16           In the morning            172           In the Morning
# 17                       NA              0                       NA
# 18              THE BADDEST            162              THE BADDEST
# 19                      불장난            197                      불장난
#
#                                      album             artist_y playcount_y  \
# 0                      Dynamite (Extended)                  BTS    80642441
# 1                The Chaos Chapter: FREEZE  TOMORROW X TOGETHER     3867105
# 2                                       NA               J-Hope     3106115
# 3                              DARK & WILD                  BTS      776556
# 4                                   LALISA                 Lisa     5342514
# 5                 The Dream Chapter: MAGIC  TOMORROW X TOGETHER     1422960
# 6   BLACKPINK 2018 Tour In Your Area Seoul            BLACKPINK      190195
# 7                                       NA           STRAY KIDS      699574
# 8                                  [12:00]                Loona      459900
# 9                                       NA                   NA           0
# 10                       BORDER : CARNIVAL              ENHYPEN      437115
# 11                                      NA                   NA           0
# 12                                      NA                   NA           0
# 13                   Border : Day One - EP              ENHYPEN      515718
# 14                                      NA                  NCT      260081
# 15                              SQUARE ONE            BLACKPINK     2897836
# 16                                      NA                 Itzy     2966250
# 17                                      NA                   NA           0
# 18                             THE BADDEST                 K/DA     2865880
# 19                              SQUARE TWO            BLACKPINK      303907
#
#    listeners_y
# 0       435982
# 1       136965
# 2       118107
# 3        66698
# 4       138270
# 5        83220
# 6         8230
# 7        41359
# 8        43076
# 9            0
# 10       33294
# 11           0
# 12           0
# 13       31728
# 14       28289
# 15      192409
# 16      132504
# 17           0
# 18      133818
# 19        7704

# %%
albuminfo_data = albuminfo_data.drop(["name_y", "album", "artist_y"], axis=1)

# %% [markdown]
# Now I have playcount and listener data!

# %%
albuminfo_data
# Out:
#                 artist_x                     name_x playcount_x listeners_x  \
# 0                    BTS                   Dynamite    28673011      248325
# 1    TOMORROW X TOGETHER  The Chaos Chapter: FREEZE    24279001      166105
# 2                 j-hope                 Hope World    23430617      195267
# 3                    BTS                DARK & WILD    16051931      200195
# 4                   Lisa                     LALISA    10477044      230773
# ..                   ...                        ...         ...         ...
# 109           Stray Kids                     NOEASY     9516958       93995
# 110                  NCT           NCT 2018 EMPATHY     6431069      149895
# 111                  BTS                DARK & WILD    16051931      200195
# 112           Stray Kids                     NOEASY     9516958       93995
# 113                  NCT           NCT 2018 EMPATHY     6431069      149895
#
#               published                                                jpg  \
# 0    11 Nov 2021, 19:26  https://lastfm.freetls.fastly.net/i/u/174s/41b...
# 1    11 Nov 2021, 13:17  https://lastfm.freetls.fastly.net/i/u/174s/d5e...
# 2    09 Sep 2021, 19:49  https://lastfm.freetls.fastly.net/i/u/174s/57b...
# 3    10 Oct 2021, 21:08  https://lastfm.freetls.fastly.net/i/u/174s/67f...
# 4    09 Sep 2021, 18:54  https://lastfm.freetls.fastly.net/i/u/174s/386...
# ..                  ...                                                ...
# 109  12 Dec 2021, 21:38  https://lastfm.freetls.fastly.net/i/u/174s/8f3...
# 110  03 Mar 2018, 02:22  https://lastfm.freetls.fastly.net/i/u/174s/a84...
# 111  10 Oct 2021, 21:08  https://lastfm.freetls.fastly.net/i/u/174s/67f...
# 112  12 Dec 2021, 21:38  https://lastfm.freetls.fastly.net/i/u/174s/8f3...
# 113  03 Mar 2018, 02:22  https://lastfm.freetls.fastly.net/i/u/174s/a84...
#
#      numtracks rank trackno                        trackname_melt  \
# 0            2    1       1                              Dynamite
# 1            8    2       1                         ANTI-ROMANTIC
# 2            7    3       1                            Hope World
# 3           14    4       1               Intro: What Am I to You
# 4            2    5       1                                LALISA
# ..         ...  ...     ...                                   ...
# 109         14    8      13                              WOLFGANG
# 110         14   15      13                         OUTRO: VISION
# 111         14    4      14  Outro : Do You Think It Makes Sense?
# 112         14    8      14                          Mixtape : OH
# 113         14   15      14              YESTODAY (Extended Ver.)
#
#     tracksdur_melt playcount_y listeners_y
# 0              199    80642441      435982
# 1              215     3867105      136965
# 2              204     3106115      118107
# 3              165      776556       66698
# 4              200     5342514      138270
# ..             ...         ...         ...
# 109          192.0      962894       40779
# 110           57.0       95244       13050
# 111          172.0       29134        3661
# 112          212.0     1092738       51049
# 113          227.0        1463          78
#
# [114 rows x 13 columns]

# %% [markdown]
# ### 5) Final adjustments
# The top album data is almost ready. Now it is time to do some final adjustments to data types and make it ready to load into Tableau.

# %%
# Let's check the data
albuminfo_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   artist_x        114 non-null    object
#  1   name_x          114 non-null    object
#  2   playcount_x     114 non-null    object
#  3   listeners_x     114 non-null    object
#  4   published       114 non-null    object
#  5   jpg             114 non-null    object
#  6   numtracks       114 non-null    int64
#  7   rank            114 non-null    object
#  8   trackno         114 non-null    object
#  9   trackname_melt  114 non-null    object
#  10  tracksdur_melt  114 non-null    object
#  11  playcount_y     114 non-null    object
#  12  listeners_y     114 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 11.7+ KB

# %%
# transform rank into integer
albuminfo_data["rank"] = albuminfo_data["rank"].copy().astype("int64")

# transform tracksdur_melt into integer
albuminfo_data["tracksdur_melt"] = albuminfo_data["tracksdur_melt"].copy().astype("int64")

# transform playcounts into integer
albuminfo_data["playcount_x"] = albuminfo_data["playcount_x"].copy().astype("int64")
albuminfo_data["listeners_x"] = albuminfo_data["listeners_x"].copy().astype("int64")
albuminfo_data["playcount_y"] = albuminfo_data["playcount_y"].copy().astype("int64")
albuminfo_data["listeners_y"] = albuminfo_data["listeners_y"].copy().astype("int64")

# transform published into datatime
albuminfo_data["published"] = pd.to_datetime(albuminfo_data["published"], errors="coerce")
albuminfo_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   artist_x        114 non-null    object
#  1   name_x          114 non-null    object
#  2   playcount_x     114 non-null    int64
#  3   listeners_x     114 non-null    int64
#  4   published       113 non-null    datetime64[ns]
#  5   jpg             114 non-null    object
#  6   numtracks       114 non-null    int64
#  7   rank            114 non-null    int64
#  8   trackno         114 non-null    object
#  9   trackname_melt  114 non-null    object
#  10  tracksdur_melt  114 non-null    int64
#  11  playcount_y     114 non-null    int64
#  12  listeners_y     114 non-null    int64
# dtypes: datetime64[ns](1), int64(7), object(5)
# memory usage: 11.7+ KB

# %%
# rename some columns
albuminfo_data = albuminfo_data.rename(columns={
    "artist_x" : "artist",
    "name_x" : "album",
    "playcount_x" : "alb_playcount",
    "listeners_x" : "alb_listeners",
    "published" : "alb_published",
    "rank" : "alb_rank",
    "trackname_melt" : "trackname",
    "tracksdur_melt" : "trackduration",
    "playcount_y" : "trc_playcount",
    "listeners_y" : "trc_listeners",
    "rank" : "alb_rank"})

#rearrange column order
albuminfo_data = albuminfo_data[["artist", "album", "alb_published", "alb_rank", "alb_playcount", "alb_listeners", "jpg", "trackno", "trackname", "trackduration", "trc_playcount", "trc_listeners"]]

#edit artist column to be all uppercase (avoid unmatches)
albuminfo_data["artist"] = albuminfo_data["artist"].apply(lambda x: x.upper())

# %%
# Data is ready!
albuminfo_data
# Out:
#                   artist                      album       alb_published  \
# 0                    BTS                   Dynamite 2021-11-11 19:26:00
# 1    TOMORROW X TOGETHER  The Chaos Chapter: FREEZE 2021-11-11 13:17:00
# 2                 J-HOPE                 Hope World 2021-09-09 19:49:00
# 3                    BTS                DARK & WILD 2021-10-10 21:08:00
# 4                   LISA                     LALISA 2021-09-09 18:54:00
# ..                   ...                        ...                 ...
# 109           STRAY KIDS                     NOEASY 2021-12-12 21:38:00
# 110                  NCT           NCT 2018 EMPATHY 2018-03-03 02:22:00
# 111                  BTS                DARK & WILD 2021-10-10 21:08:00
# 112           STRAY KIDS                     NOEASY 2021-12-12 21:38:00
# 113                  NCT           NCT 2018 EMPATHY 2018-03-03 02:22:00
#
#      alb_rank  alb_playcount  alb_listeners  \
# 0           1       28673011         248325
# 1           2       24279001         166105
# 2           3       23430617         195267
# 3           4       16051931         200195
# 4           5       10477044         230773
# ..        ...            ...            ...
# 109         8        9516958          93995
# 110        15        6431069         149895
# 111         4       16051931         200195
# 112         8        9516958          93995
# 113        15        6431069         149895
#
#                                                    jpg trackno  \
# 0    https://lastfm.freetls.fastly.net/i/u/174s/41b...       1
# 1    https://lastfm.freetls.fastly.net/i/u/174s/d5e...       1
# 2    https://lastfm.freetls.fastly.net/i/u/174s/57b...       1
# 3    https://lastfm.freetls.fastly.net/i/u/174s/67f...       1
# 4    https://lastfm.freetls.fastly.net/i/u/174s/386...       1
# ..                                                 ...     ...
# 109  https://lastfm.freetls.fastly.net/i/u/174s/8f3...      13
# 110  https://lastfm.freetls.fastly.net/i/u/174s/a84...      13
# 111  https://lastfm.freetls.fastly.net/i/u/174s/67f...      14
# 112  https://lastfm.freetls.fastly.net/i/u/174s/8f3...      14
# 113  https://lastfm.freetls.fastly.net/i/u/174s/a84...      14
#
#                                 trackname  trackduration  trc_playcount  \
# 0                                Dynamite            199       80642441
# 1                           ANTI-ROMANTIC            215        3867105
# 2                              Hope World            204        3106115
# 3                 Intro: What Am I to You            165         776556
# 4                                  LALISA            200        5342514
# ..                                    ...            ...            ...
# 109                              WOLFGANG            192         962894
# 110                         OUTRO: VISION             57          95244
# 111  Outro : Do You Think It Makes Sense?            172          29134
# 112                          Mixtape : OH            212        1092738
# 113              YESTODAY (Extended Ver.)            227           1463
#
#      trc_listeners
# 0           435982
# 1           136965
# 2           118107
# 3            66698
# 4           138270
# ..             ...
# 109          40779
# 110          13050
# 111           3661
# 112          51049
# 113             78
#
# [114 rows x 12 columns]

# %% [markdown]
# ### 6) End of processing top albums data
# Now I have a nice dataset of the top 20 k-pop albums according to LastFM stats. Let's check "BLACKPINK".

# %%
albuminfo_data[albuminfo_data["artist"]=="BLACKPINK"]
# Out:
#        artist       album       alb_published  alb_rank  alb_playcount  \
# 6   BLACKPINK   SQUARE UP 2021-07-07 16:47:00         7       10644536
# 15  BLACKPINK  SQUARE ONE 2020-12-12 21:48:00        16        6143917
# 19  BLACKPINK  SQUARE TWO 2020-12-12 21:49:00        20        5433989
# 26  BLACKPINK   SQUARE UP 2021-07-07 16:47:00         7       10644536
# 32  BLACKPINK  SQUARE ONE 2020-12-12 21:48:00        16        6143917
# 35  BLACKPINK  SQUARE TWO 2020-12-12 21:49:00        20        5433989
# 40  BLACKPINK   SQUARE UP 2021-07-07 16:47:00         7       10644536
# 48  BLACKPINK  SQUARE TWO 2020-12-12 21:49:00        20        5433989
# 53  BLACKPINK   SQUARE UP 2021-07-07 16:47:00         7       10644536
# 61  BLACKPINK  SQUARE TWO 2020-12-12 21:49:00        20        5433989
# 66  BLACKPINK   SQUARE UP 2021-07-07 16:47:00         7       10644536
# 74  BLACKPINK  SQUARE TWO 2020-12-12 21:49:00        20        5433989
#
#     alb_listeners                                                jpg trackno  \
# 6          292527  https://lastfm.freetls.fastly.net/i/u/174s/f18...       1
# 15         253888  https://lastfm.freetls.fastly.net/i/u/174s/fad...       1
# 19         211087  https://lastfm.freetls.fastly.net/i/u/174s/f91...       1
# 26         292527  https://lastfm.freetls.fastly.net/i/u/174s/f18...       2
# 32         253888  https://lastfm.freetls.fastly.net/i/u/174s/fad...       2
# 35         211087  https://lastfm.freetls.fastly.net/i/u/174s/f91...       2
# 40         292527  https://lastfm.freetls.fastly.net/i/u/174s/f18...       3
# 48         211087  https://lastfm.freetls.fastly.net/i/u/174s/f91...       3
# 53         292527  https://lastfm.freetls.fastly.net/i/u/174s/f18...       4
# 61         211087  https://lastfm.freetls.fastly.net/i/u/174s/f91...       4
# 66         292527  https://lastfm.freetls.fastly.net/i/u/174s/f18...       5
# 74         211087  https://lastfm.freetls.fastly.net/i/u/174s/f91...       5
#
#                   trackname  trackduration  trc_playcount  trc_listeners
# 6      뚜두뚜두 (DDU-DU DDU-DU)            215         190195           8230
# 15                  WHISTLE            213        2897836         192409
# 19                      불장난            197         303907           7704
# 26            Forever Young            237        3240972         170302
# 32                BOOMBAYAH            242        4024753         238646
# 35                     STAY            230        1893093         130463
# 40                   REALLY            197        2017655         125318
# 48  WHISTLE (Acoustic Ver.)            212         113698          11788
# 53              SEE U LATER            216        1836408         119738
# 61                      휘파람            211         327743           9508
# 66                    마지막처럼            213         233633           5570
# 74                BOOMBAYAH            242        4024753         238646

# %% [markdown]
# # Part B - Twitter API
# ### 1) Extract Twitter Account Data
# Now I extract twitter data using tweepy, a wrapper built for Python. The goal of this part is to find the official twitter accounts of the top kpop performers and extract a couple of their latest tweets together with their relevant metrics such as number of likes and retweets. I use the Twitter API's `search_users` method which is similar to Find People button on Twitter.com.
#
# It is quite hard to programatically get the correct Twitter accounts for each artist because Twitter search will most likely return unrelevant results. For example, unoficial twitter accounts of fans or some other celebrity that happens to have the same name of the K-pop artist we are interested in.
#
# Below, I cover three attemps I did to get the best data possible with minimal manual edits.

# %%
# Twitter API
import tweepy

# bearer_token="AAAAAAAAAAAAAAAAAAAAANIWWgEAAAAALH7nhzTyg3Tcuul4stzcHfu00Xg%3DtSAQBbebzHEIRaXjnlgzJrAEyopmtvYnj0ri5NFYVj0OpWfJ24"
consumer_key="PaT5BsKCbJXgPepUc18DXik5S"
consumer_secret="eomtEOjuU295AD8qSNgK4fF01XE1SK8KTYMjs27n0h8WJSVXe0"
# access_token="2803650524"
# access_token_secret="v3dQg2CcLgpsRgMKd3N2UUDIHWcMcqjgPQC1G3aXizJyc"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
API = tweepy.API(auth=auth)

# %% [markdown]
# ### Attempt 1
# I use the dataframe containing top albums and use Twitter's search engine to find verified users. I add the word "official" to the artist name to increase chances of getting the official twitter account of the k-pop artist. For example: "BTS official".

# %%
iden = []
artist = []
name = []
screen_name = []
followers_count = []
verified = []

for a in top_albums["artist"].unique():
    user = API.search_users(q=a+" official")
    ## while loop to find the official twitter account of musician 
    i = 0
    while (i < len(user)-1) and (user[i]._json["verified"]==False):
        i+=1
    else: 
        artist.append(a)
        iden.append(user[i]._json["id"]), 
        name.append(user[i]._json["name"]), 
        screen_name.append(user[i]._json["screen_name"]), 
        followers_count.append(user[i]._json["followers_count"]), 
        verified.append(user[i]._json["verified"])
    print("end of {}".format(a))
# Out:
# end of BTS
# end of TOMORROW X TOGETHER
# end of J-HOPE
# end of LISA
# end of BLACKPINK
# end of STRAY KIDS
# end of LOONA
# end of ROSÉ
# end of ENHYPEN
# end of NCT
# end of ITZY
# end of IZ*ONE
# end of K/DA

# %%
twitter_acct = dict(id=iden,artist=artist,name=name,screen_name=screen_name,followers_count=followers_count)
twitter_acct_df = pd.DataFrame(twitter_acct)

# Let's check results
twitter_acct_df
# Out:
#                      id               artist                       name  \
# 0            1409798257                  BTS               BTS_official
# 1   1059325677202157568  TOMORROW X TOGETHER         TXT JAPAN OFFICIAL
# 2             271444539               J-HOPE          Kaplan Foundation
# 3              18061669                 LISA        Sen. Lisa Murkowski
# 4    878204370403250176            BLACKPINK     BLACKPINK GLOBAL BLINK
# 5   1103477383158411264           STRAY KIDS  Stray Kids Japan Official
# 6    806918031964192769                LOONA        Loona Acts Concepts
# 7            3315658770                 ROSÉ        Rose Marie-Official
# 8   1293890751848275968              ENHYPEN           ENHYPEN OFFICIAL
# 9    892285827195084800                  NCT            NCT_OFFICIAL_JP
# 10  1062578718214770688                 ITZY                       ITZY
# 11  1034744720537219073               IZ*ONE             official_IZONE
# 12  1289225491233284097                 K/DA                       K/DA
#
#         screen_name  followers_count
# 0        bts_bighit         36367258
# 1     TXT_bighit_jp          2209608
# 2         KaplanFnd              732
# 3     lisamurkowski           325279
# 4   ygofficialblink          7805453
# 5     Stray_Kids_JP          1372878
# 6    official_loona               23
# 7    RoseMarie4Real            92001
# 8           ENHYPEN          4177566
# 9   NCT_OFFICIAL_JP          2965803
# 10     ITZYofficial          4251085
# 11   official_izone          1329677
# 12        KDA_MUSIC           440170

# %% [markdown]
# Looking at the results above (results as of 2021/12), we can see that for some of the artists, I was not able to get the correct official Twitter account. For example, Twitter API returned @KaplanFnd (U.S. based charity foundation) for "J-Hope" and @lisamurkowski (U.S. senator) for Lisa. Both J-Hope and Lisa does not seem to have an official Twitter account.
#
# Other accounts that are incorrect are @TXT_bighit_jp (it is an official account for Japanese audience only), @official_loona (only 23 followers and not official) and @RoseMarie4Real (American actress).
#
# ### Attempt 2
# Below, I try a different approach to get better results. I use the API to search Twitter for `artist name  + official`, then I store all accounts results into a dataframe. I sort and filter this dataframe to display only accounts with the highest number of followers for each artist.

# %%
user = []
for a in top_albums["artist"].unique():
    user.append(API.search_users(q=a+" official"))

# %%
user = list(zip(top_albums["artist"].unique(), user))

# %%
id = []
artist = []
name = []
screen_name = []
followers_count = []
verified = []
profpic = []

for a, t in user:
        for k in t:
            artist.append(a)
            id.append(k._json["id"])
            name.append(k._json["name"])
            screen_name.append(k._json["screen_name"])
            followers_count.append(k._json["followers_count"])
            verified.append(k._json["verified"])
            profpic.append(k._json["profile_image_url"])

twitter_acct2 = pd.DataFrame(dict(artist=artist, id=id, name=name,screen_name=screen_name,followers_count=followers_count, verified=verified, profpic=profpic))
twitter_acct_df2 = twitter_acct2[twitter_acct2.groupby(["artist"])["followers_count"].transform(max) == twitter_acct2['followers_count']].reset_index(drop=True)

# Check results
twitter_acct_df2
# Out:
#                  artist                   id  \
# 0                   BTS           1409798257
# 1   TOMORROW X TOGETHER  1083198663424237569
# 2                J-HOPE   812023764477157376
# 3                  LISA             18061669
# 4             BLACKPINK            408177579
# 5            STRAY KIDS   859297966581891072
# 6                 LOONA  1407603879026462722
# 7                  ROSÉ             53892481
# 8               ENHYPEN  1293890751848275968
# 9                   NCT   892285827195084800
# 10                 ITZY  1062578718214770688
# 11               IZ*ONE  1034744720537219073
# 12                 K/DA  1289225491233284097
#
#                                    name      screen_name  followers_count  \
# 0                          BTS_official       bts_bighit         36366674
# 1                          TXT OFFICIAL       TXT_bighit          8612577
# 2   J-Hope Py Official ~ HOPE WORLD☀️🐿💚   JHope_Paraguay            16749
# 3                   Sen. Lisa Murkowski    lisamurkowski           325279
# 4                             YG FAMILY   ygent_official          8230084
# 5                            Stray Kids       Stray_Kids          6876705
# 6             loonatheworld_jp_official  loonaJPofficial            80205
# 7                     Hampshire Cricket     hantscricket            96794
# 8                      ENHYPEN OFFICIAL          ENHYPEN          4177702
# 9                       NCT_OFFICIAL_JP  NCT_OFFICIAL_JP          2965739
# 10                                 ITZY     ITZYofficial          4251085
# 11                       official_IZONE   official_izone          1329704
# 12                                 K/DA        KDA_MUSIC           440170
#
#     verified                                            profpic
# 0       True  http://pbs.twimg.com/profile_images/1387421728...
# 1       True  http://pbs.twimg.com/profile_images/1416776136...
# 2      False  http://pbs.twimg.com/profile_images/1457746134...
# 3       True  http://pbs.twimg.com/profile_images/1061074014...
# 4       True  http://pbs.twimg.com/profile_images/8694461102...
# 5       True  http://pbs.twimg.com/profile_images/1458449377...
# 6      False  http://pbs.twimg.com/profile_images/1407682642...
# 7       True  http://pbs.twimg.com/profile_images/1439838811...
# 8       True  http://pbs.twimg.com/profile_images/1469110346...
# 9       True  http://pbs.twimg.com/profile_images/8994818182...
# 10      True  http://pbs.twimg.com/profile_images/1468958695...
# 11      True  http://pbs.twimg.com/profile_images/1335600379...
# 12      True  http://pbs.twimg.com/profile_images/1321436562...

# %% [markdown]
# Results seem to have got better (results as od 2021/12), but are still not perfect.
#
# - **Spot on**: @TXT_bighit and @Stray_Kids are now correct
# - **Got better**: Loona now shows a Japanese language unverified group account (seems to be a legit account, though)
# - **Still off**: NCT (not the global account), J-Hope, and Rose.
# - **Now it is off**: Blackpink now shows the official account of the management company not of the group itself.

# %% [markdown]
# It will be very difficult to find the perfect match of twitter accounts I want by only using twitter's search engine. After a quick web search, I found out that Loona does have its own official twitter account but because its name is stylized (LOOΠΔ), I wasn't able to properly find it. Also, there is no guarantee I will be able to get results as good as these once new artists with whacky names appear in our top album list.
#
# ### Attempt 3
# A better approach would be to scrape this Kpop database (curated by fans), locate the artists that I want and extract their twitter accounts: https://kpopping.com/profiles/the-groups
# <br>Let's quickly scrape twitter accounts using this method

# %%
from bs4 import BeautifulSoup
import requests

# Webscraping
site = "https://kpopping.com/profiles/the-groups"
resp = requests.get(site, timeout=5)
soup = BeautifulSoup(resp.content, "html.parser")

# %%
url = []
band = []

# Store data into dataframe
for item in soup.findAll("a", href=True):
    if item["href"][:16] == "/profiles/group/":
        url.append(item["href"])
        band.append(item.text)

kpopdb_scraped = pd.DataFrame(dict(url=url, band=band))
kpopdb_scraped.head(10)
# Out:
#                                        url                          band
# 0       /profiles/group/submission/skip-SW                    submit new
# 1                /profiles/group/CHIC-IDLE                     CHIC&IDLE
# 2  /profiles/group/Red-Velvet-IRENE-SEULGI   Red Velvet - IRENE & SEULGI
# 3                  /profiles/group/G-I-DLE                      (G)I-DLE
# 4                  /profiles/group/05Class                       05Class
# 5                      /profiles/group/100                          100%
# 6                     /profiles/group/10cm                          10cm
# 7                    /profiles/group/10X10                         10X10
# 8                      /profiles/group/14U                           14U
# 9                       /profiles/group/15                           15&

# %%
# Filter results with top artists
kpopdb_scraped["band"] = kpopdb_scraped["band"].apply(lambda x: x.upper())

twitter_acct_df_temp = twitter_acct_df2.copy()
twitter_acct_df_temp["artist2"] = twitter_acct_df_temp["artist"].apply(lambda x: x.upper())

kpopdb_scraped_top = kpopdb_scraped[kpopdb_scraped["band"].isin(twitter_acct_df_temp["artist2"])].copy()

# %%
accts = []
for idx in range(kpopdb_scraped_top.shape[0]):
    site = "https://kpopping.com"+kpopdb_scraped_top.iloc[idx,:]["url"]
    resp = requests.get(site, timeout=5)
    soup = BeautifulSoup(resp.content, "html.parser")
    for acc in soup.findAll("a", class_="fab fa-twitter", href=True):
        accts.append(acc["href"]) 
kpopdb_scraped_top["accts"] = accts

#check results
kpopdb_scraped_top
# Out:
#                             url        band  \
# 159   /profiles/group/BLACKPINK   BLACKPINK
# 188         /profiles/group/BTS         BTS
# 295     /profiles/group/ENHYPEN     ENHYPEN
# 456        /profiles/group/ITZY        ITZY
# 459      /profiles/group/IZ-ONE      IZ*ONE
# 529       /profiles/group/LOONA       LOONA
# 614         /profiles/group/NCT         NCT
# 799  /profiles/group/Stray-Kids  STRAY KIDS
#
#                                          accts
# 159              https://twitter.com/blackpink
# 188                https://twitter.com/BTS_twt
# 295                https://twitter.com/ENHYPEN
# 456           https://twitter.com/ITZYOfficial
# 459         https://twitter.com/official_izone
# 529  https://twitter.com/loonatheworld?lang=en
# 614              https://twitter.com/nctsmtown
# 799        https://twitter.com/Stray_Kids?s=09

# %% [markdown]
# We can see above that the kpop database does not have all artists I get from LastFM. For example, K/DA does not appear because it does not exist in the database. I also fail TOMORROW X TOGETHER because apparently this group is better known by its abbreviated name - "TXT" - and this is how it is written in the databse.
#
# However, for all other artists, it seems that I succeed in getting correct official twitter accounts. Let's now use the Twitter API to get those data and build our own database by combining results from Attempr 2 and the scraped results.
#
# To do that I will need to first edit the `accts` column and get screen_names.

# %%
kpopdb_scraped_top["screen_name"] = kpopdb_scraped_top["accts"].apply(lambda x: x.split("/")[-1])
kpopdb_scraped_top["screen_name"] = kpopdb_scraped_top["screen_name"].apply(lambda x: x.split("?")[0])
kpopdb_scraped_top
# Out:
#                             url        band  \
# 159   /profiles/group/BLACKPINK   BLACKPINK
# 188         /profiles/group/BTS         BTS
# 295     /profiles/group/ENHYPEN     ENHYPEN
# 456        /profiles/group/ITZY        ITZY
# 459      /profiles/group/IZ-ONE      IZ*ONE
# 529       /profiles/group/LOONA       LOONA
# 614         /profiles/group/NCT         NCT
# 799  /profiles/group/Stray-Kids  STRAY KIDS
#
#                                          accts     screen_name
# 159              https://twitter.com/blackpink       blackpink
# 188                https://twitter.com/BTS_twt         BTS_twt
# 295                https://twitter.com/ENHYPEN         ENHYPEN
# 456           https://twitter.com/ITZYOfficial    ITZYOfficial
# 459         https://twitter.com/official_izone  official_izone
# 529  https://twitter.com/loonatheworld?lang=en   loonatheworld
# 614              https://twitter.com/nctsmtown       nctsmtown
# 799        https://twitter.com/Stray_Kids?s=09      Stray_Kids

# %% [markdown]
# Now I use Twitter API to extract user information. Same procedure I used above, so I will skip all commentary.

# %%
users = []
for sn in range(kpopdb_scraped_top.shape[0]):
    user = API.get_user(screen_name=kpopdb_scraped_top.iloc[sn,:]["screen_name"])
    users.append(user)

# %%
band_users = list(zip(kpopdb_scraped_top["band"], users))

# %%
id = []
artist = []
name = []
screen_name = []
followers_count = []
verified = []
profpic = []

for a, k in band_users:
        artist.append(a)
        id.append(k._json["id"])
        name.append(k._json["name"])
        screen_name.append(k._json["screen_name"])
        followers_count.append(k._json["followers_count"])
        verified.append(k._json["verified"])
        profpic.append(k._json["profile_image_url"])

twitter_acct_df3 = pd.DataFrame(dict(artist=artist, id=id, name=name,screen_name=screen_name,followers_count=followers_count, verified=verified, profpic=profpic))

# check results
twitter_acct_df3
# Out:
#        artist                   id               name     screen_name  \
# 0   BLACKPINK  1273850774380883975  BLACKPINKOFFICIAL       BLACKPINK
# 1         BTS            335141638              방탄소년단         BTS_twt
# 2     ENHYPEN  1293890751848275968   ENHYPEN OFFICIAL         ENHYPEN
# 3        ITZY  1062578718214770688               ITZY    ITZYofficial
# 4      IZ*ONE  1034744720537219073     official_IZONE  official_izone
# 5       LOONA   770959712791597056      이달의 소녀(LOOΠΔ)   loonatheworld
# 6         NCT           4811011050                NCT       NCTsmtown
# 7  STRAY KIDS   859297966581891072         Stray Kids      Stray_Kids
#
#    followers_count  verified  \
# 0          5626296      True
# 1         42725656      True
# 2          4177569      True
# 3          4251088      True
# 4          1329678      True
# 5           840912      True
# 6          8064592      True
# 7          6876709      True
#
#                                              profpic
# 0  http://pbs.twimg.com/profile_images/1311878593...
# 1  http://pbs.twimg.com/profile_images/1437401193...
# 2  http://pbs.twimg.com/profile_images/1469110346...
# 3  http://pbs.twimg.com/profile_images/1468958695...
# 4  http://pbs.twimg.com/profile_images/1335600379...
# 5  http://pbs.twimg.com/profile_images/7709919458...
# 6  http://pbs.twimg.com/profile_images/1469230267...
# 7  http://pbs.twimg.com/profile_images/1458449377...

# %% [markdown]
# Now I have two good tables containing twitter accounts of K-pop artists (Attemp 2 and Attemp 3). The goal now is to grab the correct twitter accounts from each table.
# - Attempt 3) Scraped data has correct twitter accounts but is incomplete.
# - Attempt 2) Data extracted using Twitter API search method is complete, but some entries are incorrect.
#
# Below, I build a "complete" dataset by concatenating tables from both attempts, then I remove all duplicates from the "Twitter API" data. Next, I remove the data for accounts that are obviously of non-K-pop stars (Lisa and Rose).

# %%
#build "order" column so that I can tell Python the exact duplicates to remove (keep the "1s")
twitter_acct_df3["order"]=1
twitter_acct_df3
# Out:
#        artist                   id               name     screen_name  \
# 0   BLACKPINK  1273850774380883975  BLACKPINKOFFICIAL       BLACKPINK
# 1         BTS            335141638              방탄소년단         BTS_twt
# 2     ENHYPEN  1293890751848275968   ENHYPEN OFFICIAL         ENHYPEN
# 3        ITZY  1062578718214770688               ITZY    ITZYofficial
# 4      IZ*ONE  1034744720537219073     official_IZONE  official_izone
# 5       LOONA   770959712791597056      이달의 소녀(LOOΠΔ)   loonatheworld
# 6         NCT           4811011050                NCT       NCTsmtown
# 7  STRAY KIDS   859297966581891072         Stray Kids      Stray_Kids
#
#    followers_count  verified  \
# 0          5626296      True
# 1         42725656      True
# 2          4177569      True
# 3          4251088      True
# 4          1329678      True
# 5           840912      True
# 6          8064592      True
# 7          6876709      True
#
#                                              profpic  order
# 0  http://pbs.twimg.com/profile_images/1311878593...      1
# 1  http://pbs.twimg.com/profile_images/1437401193...      1
# 2  http://pbs.twimg.com/profile_images/1469110346...      1
# 3  http://pbs.twimg.com/profile_images/1468958695...      1
# 4  http://pbs.twimg.com/profile_images/1335600379...      1
# 5  http://pbs.twimg.com/profile_images/7709919458...      1
# 6  http://pbs.twimg.com/profile_images/1469230267...      1
# 7  http://pbs.twimg.com/profile_images/1458449377...      1

# %%
#build "order" column so that I can tell Python the exact duplicates to remove (keep the "1s")
twitter_acct_df2["order"]=2
twitter_acct_df2
# Out:
#                  artist                   id  \
# 0                   BTS           1409798257
# 1   TOMORROW X TOGETHER  1083198663424237569
# 2                J-HOPE   812023764477157376
# 3                  LISA             18061669
# 4             BLACKPINK            408177579
# 5            STRAY KIDS   859297966581891072
# 6                 LOONA  1407603879026462722
# 7                  ROSÉ             53892481
# 8               ENHYPEN  1293890751848275968
# 9                   NCT   892285827195084800
# 10                 ITZY  1062578718214770688
# 11               IZ*ONE  1034744720537219073
# 12                 K/DA  1289225491233284097
#
#                                    name      screen_name  followers_count  \
# 0                          BTS_official       bts_bighit         36366674
# 1                          TXT OFFICIAL       TXT_bighit          8612577
# 2   J-Hope Py Official ~ HOPE WORLD☀️🐿💚   JHope_Paraguay            16749
# 3                   Sen. Lisa Murkowski    lisamurkowski           325279
# 4                             YG FAMILY   ygent_official          8230084
# 5                            Stray Kids       Stray_Kids          6876705
# 6             loonatheworld_jp_official  loonaJPofficial            80205
# 7                     Hampshire Cricket     hantscricket            96794
# 8                      ENHYPEN OFFICIAL          ENHYPEN          4177702
# 9                       NCT_OFFICIAL_JP  NCT_OFFICIAL_JP          2965739
# 10                                 ITZY     ITZYofficial          4251085
# 11                       official_IZONE   official_izone          1329704
# 12                                 K/DA        KDA_MUSIC           440170
#
#     verified                                            profpic  order
# 0       True  http://pbs.twimg.com/profile_images/1387421728...      2
# 1       True  http://pbs.twimg.com/profile_images/1416776136...      2
# 2      False  http://pbs.twimg.com/profile_images/1457746134...      2
# 3       True  http://pbs.twimg.com/profile_images/1061074014...      2
# 4       True  http://pbs.twimg.com/profile_images/8694461102...      2
# 5       True  http://pbs.twimg.com/profile_images/1458449377...      2
# 6      False  http://pbs.twimg.com/profile_images/1407682642...      2
# 7       True  http://pbs.twimg.com/profile_images/1439838811...      2
# 8       True  http://pbs.twimg.com/profile_images/1469110346...      2
# 9       True  http://pbs.twimg.com/profile_images/8994818182...      2
# 10      True  http://pbs.twimg.com/profile_images/1468958695...      2
# 11      True  http://pbs.twimg.com/profile_images/1335600379...      2
# 12      True  http://pbs.twimg.com/profile_images/1321436562...      2

# %%
# keep only verified accounts, then concatenate tables.
twitter_acct_df4 = pd.concat([twitter_acct_df2, twitter_acct_df3], axis=0)

# drop duplicates by keeping entries from table 1 (scraped data)
twitter_acct_df5 = twitter_acct_df4[twitter_acct_df4["verified"]].sort_values(["artist", "order"]).drop_duplicates("artist", keep="first")
twitter_acct_df5
# Out:
#                  artist                   id                 name  \
# 0             BLACKPINK  1273850774380883975    BLACKPINKOFFICIAL
# 1                   BTS            335141638                방탄소년단
# 2               ENHYPEN  1293890751848275968     ENHYPEN OFFICIAL
# 3                  ITZY  1062578718214770688                 ITZY
# 4                IZ*ONE  1034744720537219073       official_IZONE
# 12                 K/DA  1289225491233284097                 K/DA
# 3                  LISA             18061669  Sen. Lisa Murkowski
# 5                 LOONA   770959712791597056        이달의 소녀(LOOΠΔ)
# 6                   NCT           4811011050                  NCT
# 7                  ROSÉ             53892481    Hampshire Cricket
# 7            STRAY KIDS   859297966581891072           Stray Kids
# 1   TOMORROW X TOGETHER  1083198663424237569         TXT OFFICIAL
#
#        screen_name  followers_count  verified  \
# 0        BLACKPINK          5626296      True
# 1          BTS_twt         42725656      True
# 2          ENHYPEN          4177569      True
# 3     ITZYofficial          4251088      True
# 4   official_izone          1329678      True
# 12       KDA_MUSIC           440170      True
# 3    lisamurkowski           325279      True
# 5    loonatheworld           840912      True
# 6        NCTsmtown          8064592      True
# 7     hantscricket            96794      True
# 7       Stray_Kids          6876709      True
# 1       TXT_bighit          8612577      True
#
#                                               profpic  order
# 0   http://pbs.twimg.com/profile_images/1311878593...      1
# 1   http://pbs.twimg.com/profile_images/1437401193...      1
# 2   http://pbs.twimg.com/profile_images/1469110346...      1
# 3   http://pbs.twimg.com/profile_images/1468958695...      1
# 4   http://pbs.twimg.com/profile_images/1335600379...      1
# 12  http://pbs.twimg.com/profile_images/1321436562...      2
# 3   http://pbs.twimg.com/profile_images/1061074014...      2
# 5   http://pbs.twimg.com/profile_images/7709919458...      1
# 6   http://pbs.twimg.com/profile_images/1469230267...      1
# 7   http://pbs.twimg.com/profile_images/1439838811...      2
# 7   http://pbs.twimg.com/profile_images/1458449377...      1
# 1   http://pbs.twimg.com/profile_images/1416776136...      2

# %%
#id that are not kpop stars (remove from table)
notkpopstar = [53892481, 18061669]

# %% [markdown]
# `notkpopstar` is a list of errors that I use as a reference to remove wrong entries from my dataset. In the future, when I come back to this script to refresh my dashboard, I will need to eyeball `twitter_acct_df5` table and keep adding the ids of wrong Twitter accounts that were newly added to the dataset.
#
# There must be a smarter way to do this, but I will just leave the way it since it is not a lot of work to add id numbers to the list.

# %%
twitter_acct_df5 = twitter_acct_df5[~twitter_acct_df5["id"].isin(notkpopstar)].reset_index(drop=True)

# check results
twitter_acct_df5
# Out:
#                 artist                   id               name  \
# 0            BLACKPINK  1273850774380883975  BLACKPINKOFFICIAL
# 1                  BTS            335141638              방탄소년단
# 2              ENHYPEN  1293890751848275968   ENHYPEN OFFICIAL
# 3                 ITZY  1062578718214770688               ITZY
# 4               IZ*ONE  1034744720537219073     official_IZONE
# 5                 K/DA  1289225491233284097               K/DA
# 6                LOONA   770959712791597056      이달의 소녀(LOOΠΔ)
# 7                  NCT           4811011050                NCT
# 8           STRAY KIDS   859297966581891072         Stray Kids
# 9  TOMORROW X TOGETHER  1083198663424237569       TXT OFFICIAL
#
#       screen_name  followers_count  verified  \
# 0       BLACKPINK          5626296      True
# 1         BTS_twt         42725656      True
# 2         ENHYPEN          4177569      True
# 3    ITZYofficial          4251088      True
# 4  official_izone          1329678      True
# 5       KDA_MUSIC           440170      True
# 6   loonatheworld           840912      True
# 7       NCTsmtown          8064592      True
# 8      Stray_Kids          6876709      True
# 9      TXT_bighit          8612577      True
#
#                                              profpic  order
# 0  http://pbs.twimg.com/profile_images/1311878593...      1
# 1  http://pbs.twimg.com/profile_images/1437401193...      1
# 2  http://pbs.twimg.com/profile_images/1469110346...      1
# 3  http://pbs.twimg.com/profile_images/1468958695...      1
# 4  http://pbs.twimg.com/profile_images/1335600379...      1
# 5  http://pbs.twimg.com/profile_images/1321436562...      2
# 6  http://pbs.twimg.com/profile_images/7709919458...      1
# 7  http://pbs.twimg.com/profile_images/1469230267...      1
# 8  http://pbs.twimg.com/profile_images/1458449377...      1
# 9  http://pbs.twimg.com/profile_images/1416776136...      2

# %% [markdown]
# Before I proceed to the next step, I will save the profile pictures so that I can use those in the dashboard.

# %%
# loop through every profile picture and save it
# I use generic file names so that it is easy to update
for idx, url in enumerate(twitter_acct_df5["profpic"]):
    filename = twitter_acct_df5.loc[idx,"screen_name"]+"_pic"+url[-4:]
    urllib.request.urlretrieve(url, filename)
    print("saved "+filename)
# Out:
# saved BLACKPINK_pic.jpg
# saved BTS_twt_pic.jpg
# saved ENHYPEN_pic.jpg
# saved ITZYofficial_pic.jpg
# saved official_izone_pic.jpg
# saved KDA_MUSIC_pic.jpg
# saved loonatheworld_pic.jpg
# saved NCTsmtown_pic.jpg
# saved Stray_Kids_pic.jpg
# saved TXT_bighit_pic.jpg

# %% [markdown]
# ### 2) Extract Twitter Timelines
# The next step is to extract the timelines of the twitter accounts found above using the `API.user_timeline` method. Twitter API will return the latest 20 tweets from each acount (I set the API to exclude replies and retweets, so for some accounts it might be less than 20 results)

# %%
t_artist = []
t_text = []
t_date = []
t_rtcount = []
t_fvcount = []

for k,i in enumerate(twitter_acct_df5["id"]):
    print(twitter_acct_df5["artist"][k])
    tweets = API.user_timeline(user_id=i, exclude_replies=True, include_rts=False)
    for t in range(len(tweets)):
        t_artist.append(twitter_acct_df5["artist"][k])
        t_text.append(tweets[t]._json["text"])
        t_date.append(tweets[t]._json["created_at"])
        t_rtcount.append(tweets[t]._json["retweet_count"])
        t_fvcount.append(tweets[t]._json["favorite_count"])
# Out:
# BLACKPINK
# BTS
# ENHYPEN
# ITZY
# IZ*ONE
# K/DA
# LOONA
# NCT
# STRAY KIDS
# TOMORROW X TOGETHER

# %%
tweet = dict(t_artist=t_artist, t_text=t_text, t_date=t_date, t_rtcount=t_rtcount, t_fvcount=t_fvcount)
tweet_df = pd.DataFrame(tweet)

# %% [markdown]
# Chck results for twitter timelines. This is the results for BLACKPINK.

# %%
tweet_df[tweet_df["t_artist"]=="BLACKPINK"]
# Out:
#      t_artist                                             t_text  \
# 0   BLACKPINK  👉Hit you with that #DDUDUDDUDU👉\nItems inspire...
# 1   BLACKPINK  #ESCAPE2021 IN YOUR AREA https://t.co/Dbx8tiDw...
# 2   BLACKPINK  #BLACKPINK ‘Forever Young’ DANCE PRACTICE VIDE...
# 3   BLACKPINK  #BLACKPINK ‘STAY’ M/V HITS 300 MILLION VIEWS @...
# 4   BLACKPINK  Thank you so much for streaming #LALISA and #M...
# 5   BLACKPINK  Thank you so much for streaming #OnTheGround a...
# 6   BLACKPINK  #BLACKPINK's #THEALBUM is now in #DolbyAtmos 🎶...
# 7   BLACKPINK  #LISA -LALISA- PHOTOBOOK [SPECIAL EDITION]\nPr...
# 8   BLACKPINK  #LISA FIRST SINGLE VINYL LP LALISA [LIMITED ED...
# 9   BLACKPINK  #LISA ‘MONEY’ EXCLUSIVE PERFORMANCE VIDEO HITS...
# 10  BLACKPINK  #LISA has been nominated for #2021MAMA Worldwi...
# 11  BLACKPINK  #ROSÉ has been nominated for #2021MAMA Worldwi...
# 12  BLACKPINK  time for you to watch #LISA's #MONEY @iHeartRa...
# 13  BLACKPINK  #BLACKPINK '마지막처럼 (AS IF IT'S YOUR LAST)' M/V ...
#
#                             t_date  t_rtcount  t_fvcount
# 0   Tue Dec 21 08:01:17 +0000 2021       8048      57259
# 1   Thu Dec 16 04:30:24 +0000 2021      19465     107397
# 2   Mon Dec 13 01:37:25 +0000 2021      20562      94224
# 3   Sat Dec 11 23:01:54 +0000 2021      30603     123454
# 4   Thu Dec 09 08:44:19 +0000 2021      24778      91178
# 5   Thu Dec 09 08:43:57 +0000 2021      15895      65162
# 6   Wed Dec 08 09:06:36 +0000 2021       9623      53878
# 7   Wed Dec 08 02:01:43 +0000 2021      18559      82517
# 8   Tue Nov 30 03:02:33 +0000 2021      20841     106785
# 9   Sun Nov 28 23:01:08 +0000 2021      38312     133118
# 10  Thu Nov 25 09:17:30 +0000 2021      27999      93047
# 11  Thu Nov 25 09:16:13 +0000 2021      21441      72633
# 12  Sun Nov 21 02:26:54 +0000 2021      12471      63039
# 13  Thu Nov 18 08:07:49 +0000 2021      27098     118677

# %% [markdown]
# ### 3) Merge Twitter datasets (and some small adjustments to the data)
# Now I merge the dataset containing twitter accounts with twitter timelines to get a single twitter dataset.

# %%
twitter_data = twitter_acct_df5.merge(right=tweet_df, left_on="artist", right_on="t_artist")
twitter_data
# Out:
#                   artist                   id               name screen_name  \
# 0              BLACKPINK  1273850774380883975  BLACKPINKOFFICIAL   BLACKPINK
# 1              BLACKPINK  1273850774380883975  BLACKPINKOFFICIAL   BLACKPINK
# 2              BLACKPINK  1273850774380883975  BLACKPINKOFFICIAL   BLACKPINK
# 3              BLACKPINK  1273850774380883975  BLACKPINKOFFICIAL   BLACKPINK
# 4              BLACKPINK  1273850774380883975  BLACKPINKOFFICIAL   BLACKPINK
# ..                   ...                  ...                ...         ...
# 133  TOMORROW X TOGETHER  1083198663424237569       TXT OFFICIAL  TXT_bighit
# 134  TOMORROW X TOGETHER  1083198663424237569       TXT OFFICIAL  TXT_bighit
# 135  TOMORROW X TOGETHER  1083198663424237569       TXT OFFICIAL  TXT_bighit
# 136  TOMORROW X TOGETHER  1083198663424237569       TXT OFFICIAL  TXT_bighit
# 137  TOMORROW X TOGETHER  1083198663424237569       TXT OFFICIAL  TXT_bighit
#
#      followers_count  verified  \
# 0            5626296      True
# 1            5626296      True
# 2            5626296      True
# 3            5626296      True
# 4            5626296      True
# ..               ...       ...
# 133          8612577      True
# 134          8612577      True
# 135          8612577      True
# 136          8612577      True
# 137          8612577      True
#
#                                                profpic  order  \
# 0    http://pbs.twimg.com/profile_images/1311878593...      1
# 1    http://pbs.twimg.com/profile_images/1311878593...      1
# 2    http://pbs.twimg.com/profile_images/1311878593...      1
# 3    http://pbs.twimg.com/profile_images/1311878593...      1
# 4    http://pbs.twimg.com/profile_images/1311878593...      1
# ..                                                 ...    ...
# 133  http://pbs.twimg.com/profile_images/1416776136...      2
# 134  http://pbs.twimg.com/profile_images/1416776136...      2
# 135  http://pbs.twimg.com/profile_images/1416776136...      2
# 136  http://pbs.twimg.com/profile_images/1416776136...      2
# 137  http://pbs.twimg.com/profile_images/1416776136...      2
#
#                 t_artist                                             t_text  \
# 0              BLACKPINK  👉Hit you with that #DDUDUDDUDU👉\nItems inspire...
# 1              BLACKPINK  #ESCAPE2021 IN YOUR AREA https://t.co/Dbx8tiDw...
# 2              BLACKPINK  #BLACKPINK ‘Forever Young’ DANCE PRACTICE VIDE...
# 3              BLACKPINK  #BLACKPINK ‘STAY’ M/V HITS 300 MILLION VIEWS @...
# 4              BLACKPINK  Thank you so much for streaming #LALISA and #M...
# ..                   ...                                                ...
# 133  TOMORROW X TOGETHER  TXT (투모로우바이투게더) 'Sweet Dreams'\n(https://t.co/...
# 134  TOMORROW X TOGETHER  #투모로우바이투게더 가 #MOA 에게 선물하는 첫 번째 캐럴🎁\n'Sweet Dre...
# 135  TOMORROW X TOGETHER  [#TTIME] #휴닝카이 에게 주어진 2번의 유리 깨기 기회! 멋지게 성공할 수 ...
# 136  TOMORROW X TOGETHER  TO DO X TXT - EP.63 해피 홀리데이 파티 1편(Happy Holida...
# 137  TOMORROW X TOGETHER  [EPISODE] #투모로우바이투게더 #VOGUE December Issue Pho...
#
#                              t_date  t_rtcount  t_fvcount
# 0    Tue Dec 21 08:01:17 +0000 2021       8048      57259
# 1    Thu Dec 16 04:30:24 +0000 2021      19465     107397
# 2    Mon Dec 13 01:37:25 +0000 2021      20562      94224
# 3    Sat Dec 11 23:01:54 +0000 2021      30603     123454
# 4    Thu Dec 09 08:44:19 +0000 2021      24778      91178
# ..                              ...        ...        ...
# 133  Wed Dec 22 09:00:18 +0000 2021      27020      87918
# 134  Wed Dec 22 06:00:04 +0000 2021      26945     102016
# 135  Wed Dec 22 05:00:29 +0000 2021       8974      55678
# 136  Mon Dec 20 12:00:06 +0000 2021      11405      66069
# 137  Sun Dec 19 11:01:01 +0000 2021      11796      62252
#
# [138 rows x 13 columns]

# %% [markdown]
# Change the datatype for date

# %%
twitter_data["t_date"] = twitter_data["t_date"].apply(lambda x : pd.to_datetime(x, errors="coerce").date())
twitter_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 0 to 137
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   artist           138 non-null    object
#  1   id               138 non-null    int64
#  2   name             138 non-null    object
#  3   screen_name      138 non-null    object
#  4   followers_count  138 non-null    int64
#  5   verified         138 non-null    bool
#  6   profpic          138 non-null    object
#  7   order            138 non-null    int64
#  8   t_artist         138 non-null    object
#  9   t_text           138 non-null    object
#  10  t_date           138 non-null    object
#  11  t_rtcount        138 non-null    int64
#  12  t_fvcount        138 non-null    int64
# dtypes: bool(1), int64(5), object(7)
# memory usage: 14.2+ KB

# %%
# In Tableau, I will need to match album data and Twitter data using artist name. I set all names in uppercase to make sure all artists will match.
twitter_data["artist"] = twitter_data["artist"].apply(lambda x: x.upper())

# Twitter dataset is ready! 
twitter_data.to_excel("twitter_data.xlsx", sheet_name="Sheet1", index=False)
twitter_data["artist"].unique()
# Out:
# array(['BLACKPINK', 'BTS', 'ENHYPEN', 'ITZY', 'IZ*ONE', 'K/DA', 'LOONA',
#        'NCT', 'STRAY KIDS', 'TOMORROW X TOGETHER'], dtype=object)

# %%
# In Tableau, I will need to match album data and Twitter data using artist name. I set all names in uppercase to make sure all artists will match.
albuminfo_data["artist"] = albuminfo_data["artist"].apply(lambda x: x.upper())

# Album dataset is ready! 
albuminfo_data.to_csv("albuminfo_data.csv", index=False)
albuminfo_data["artist"].unique()
# Out:
# array(['BTS', 'TOMORROW X TOGETHER', 'J-HOPE', 'LISA', 'BLACKPINK',
#        'STRAY KIDS', 'LOONA', 'ROSÉ', 'ENHYPEN', 'NCT', 'ITZY', 'IZ*ONE',
#        'K/DA'], dtype=object)

# %% [markdown]
# # Part 3) Visualize
# The last step is to visualize the data in Tableau. See below a screenshot of it. The "K-Pop Monitor" (as I call it) has basic visualizations of top K-pop albums according to LastFM. The user needs to click one an album/artist to refresh the other charts, including the Twitter Analysis part at the bottom of the dashboard.
#
# This is not a particularly complex dashboard and it does not show any ground breaking analysis, but it is a good way to quickly grasp the K-pop industry in a "data-driven" way. The data grabbing process was streamlined so that I can update the dashboard with the latest tweets and album / track data by simply rerunning this Python notebook. The problem would be to update the pictures as I needed to manually setup the pictures inside Tableau.
#
# Check the dashboard at my [Tableau Public Account](https://public.tableau.com/views/projectk_16396618958480/Dashboard1?:language=en-GB&publish=yes&:display_count=n&:origin=viz_share_link).

# %% [markdown]
# ![](dashboard_ss.jpg)

# %% [markdown]
# This is the end of project K! Thanks for reading!
